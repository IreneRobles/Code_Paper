# %%
ENV["Code"] = "../../Code"
for folder in readdir(ENV["Code"]); push!(LOAD_PATH, normpath(ENV["Code"], folder));end

include(ENV["Code"]*"/../Code_Paper/Databases/Cuartero2018.jl")
include(ENV["Code"]*"/../Code_Paper/Databases/mm9.jl")
include(ENV["Code"]*"/../Code_Paper/Code/meanmRNAcounts_BSBF.jl")
# Out:
# ┌ Info: Installing pyqt package to avoid buggy tkagg backend.
# └ @ PyPlot /Users/irene/.julia/packages/PyPlot/XHEG0/src/init.jl:118
# plot_bs (generic function with 1 method)

# %%
il12b = get_genedata("Il12b_intron_BD")
hss1 = get_genedata("HSS1_BD")
egr2 = get_genedata("Il12b_intron_BD")
egr2enh = get_genedata("HSS1_BD")
# Out:
# 69605×46 DataFrame
#    Row │ Image                              Cell        AREA_cell  AREA_nuc  N ⋯
#        │ String                             String15    Float64    Float64   I ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_1      3215.5    3034.5    ⋯
#      2 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_2      2172.0    2014.0
#      3 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_3      3109.5    2923.0
#      4 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_4      3019.0    2843.5
#      5 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_5      3068.5    2893.5    ⋯
#      6 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_6      3097.0    2915.0
#      7 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_7      2813.5    2645.0
#      8 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_8      4699.0    4471.5
#      9 │ Il12bBD_failedu1v1_25May21_WTRad…  Cell_CP_9      3077.5    2896.5    ⋯
# ...

# %%
include("HiddenCode.jl")

function bftest(BFs_gene)

TEST = BF_test(BFs_gene, "$intronname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ])

CSV.write("$AnalysisName/"*"$intronname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$intronname"*"_BFs_TEST.csv", TEST)
    
    return TEST
    
end


function bftest2(BFs_gene)

TEST = BF_test(BFs_gene, "$intronname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],  
        ["WT_BD2-5u-LPS", "Rad21KO_BD2-5u-LPS"],
        ["WT_PAN-LPS", "Rad21KO_PAN-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ["WT_BD2-LPS", "WT_BD2-5u-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_BD2-5u-LPS"],
        
        ])

CSV.write("$AnalysisName/"*"$intronname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$intronname"*"_BFs_TEST.csv", TEST)
    
    return TEST
    
end

function testh4(TEST,h1,h2,h3,h4)
    

ii = 0
h = h1
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")


h = h2
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")


h = h3
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

h = h4
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
    
end

function testh6(TEST,h1,h2,h3,h4, h5, h6)
    

ii = 0
h = h1
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")


h = h2
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")


h = h3
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

h = h4
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
    
h = h5
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

h = h6
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
    
end


function BF_Il12b_WTRad21()
    
exps = all_gene
expvector = [exps[exps[!,:Rep].==ii, :] for ii in unique(exps[!,:Rep])]
BFs_gene = calculatesumary(expvector...,limit = il12b)
TEST = bftest(BFs_gene)

title("WT and Rad21KO")
Seaborn.stripplot(data = Pandas.DataFrame(BFs_gene), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray","red",], order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
Seaborn.boxplot(data = Pandas.DataFrame(BFs_gene), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray","red",], order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])

xlabel("Treatment")
ylabel("Gene burst freq.")


h1,h2,h3,h4 = 0.03, 0.12, 0.05, 0.08

testh4(TEST,h1,h2,h3,h4)

ylim(0, 0.2);legend_removal();pretty_axes2();line075black();squareplot();xticks(rotation=90)

end

function BF_Il12b_WT()
    exps = all_gene
expvector = [exps[exps[!,:Rep].==ii, :] for ii in unique(exps[!,:Rep])]
BFs_gene = calculatesumary(expvector...,limit = il12b)



TEST = BF_test(BFs_gene, "$intronname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ])

CSV.write("$AnalysisName/"*"$intronname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$intronname"*"_BFs_TEST.csv", TEST)
    
title("WT")

BFs_gene_sub = BFs_gene[BFs_gene[!, :Genotype].== "WT", :]

Seaborn.stripplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray" ], order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
Seaborn.boxplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray"], order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
ylabel("Gene burst freq.")
xlabel("Treatment")
plt.tight_layout()

h1,h2,h3, h4 = 0.11, 0.14, 0.17, 0.11

ii = 0
h = h1
xy = [-0+ii, 1+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[5, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
h = h2
xy = [1, 2]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[6, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h3
xy = [1, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[7, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h4
xy = [2, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[8, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ylim(0, 0.2);legend_removal();pretty_axes2();line075black();squareplot();xticks(rotation=90)

end
function BF_Il12b_Rad21()
    
    exps = all_gene
expvector = [exps[exps[!,:Rep].==ii, :] for ii in unique(exps[!,:Rep])]
BFs_gene = calculatesumary(expvector...,limit = il12b)
TEST = BF_test(BFs_gene, "$intronname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ])

CSV.write("$AnalysisName/"*"$intronname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$intronname"*"_BFs_TEST.csv", TEST)
    
    title("Rad21KO")
    

BFs_gene_sub = BFs_gene[BFs_gene[!, :Genotype].== "Rad21KO", :]

Seaborn.stripplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["red"],
order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
Seaborn.boxplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["red"],
order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
ylabel("Gene burst freq.")
xlabel("Treatment")
plt.tight_layout()

h1,h2,h3, h4 = 0.02, 0.04, 0.1, 0.073

ii = 0
h = h1
xy = [-0+ii, 1+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[9, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")



h = h2
xy = [1, 2]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[10, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h3
xy = [1, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[11, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h4
xy = [2, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[12, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")



ylim(0, 0.2);legend_removal();pretty_axes2();line075black();squareplot();xticks(rotation=90)

plt.tight_layout()
end



function BF_HSS1_WTRad21()

exps = all_ehn
expvector = [exps[exps[!,:Rep].==ii, :] for ii in unique(exps[!,:Rep])]
BFs_gene = calculatesumary(expvector...,limit = hss1)

ylimit = 0.34
u = 0.01



TEST = BF_test(BFs_gene, "$ehnname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ])

CSV.write("$AnalysisName/"*"$ehnname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$ehnname"*"_BFs_TEST.csv", TEST)


title("WT and Rad21KO")
Seaborn.stripplot(data = Pandas.DataFrame(BFs_gene), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray","red", "darkgray"], order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
Seaborn.boxplot(data = Pandas.DataFrame(BFs_gene), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray","red", "darkgray"], order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
ylabel("Enh burst freq.")


h1,h2,h3,h4 = 0.15, 0.3, 0.16, 0.2

xlabel("Treatment")
ylabel("Enh burst freq.")

ii = 0
h = h1
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+u]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")


h = h2
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+u]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")


h = h3
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+u]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

h = h4
xy = [-0.25+ii, .25+ii]; xy2 = [Statistics.mean(xy) , h+u]
plt.plot(xy, [h, h], c = "black")
pval = TEST[ii+=1, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
ylim(0, ylimit);legend_removal();pretty_axes2();line075black();squareplot();xticks(rotation=90)
end

function BF_HSS1_WT()
    exps = all_ehn
expvector = [exps[exps[!,:Rep].==ii, :] for ii in unique(exps[!,:Rep])]
BFs_gene = calculatesumary(expvector...,limit = hss1)

ylimit = 0.34
u = 0.01


TEST = BF_test(BFs_gene, "$ehnname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ])

CSV.write("$AnalysisName/"*"$ehnname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$ehnname"*"_BFs_TEST.csv", TEST)
   title("WT")

BFs_gene_sub = BFs_gene[BFs_gene[!, :Genotype].== "WT", :]

Seaborn.stripplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray" ],order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
Seaborn.boxplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["darkgray"],order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
ylabel("Enh burst freq.")
xlabel("Treatment")
plt.tight_layout()

h1,h2,h3, h4 = 0.2, 0.24, 0.28, 0.25

ii = 0
h = h1
xy = [-0+ii, 1+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[5, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
h = h2
xy = [1, 2]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[6, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h3
xy = [1, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[7, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h4
xy = [2, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[8, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ylim(0, ylimit);legend_removal();pretty_axes2();line075black();squareplot();xticks(rotation=90)

end

function BF_HSS1_Rad21()
    exps = all_ehn
expvector = [exps[exps[!,:Rep].==ii, :] for ii in unique(exps[!,:Rep])]
BFs_gene = calculatesumary(expvector...,limit = hss1)

ylimit = 0.34
u = 0.01


TEST = BF_test(BFs_gene, "$ehnname", :N_TSS, [
        ["Rad21KO_DMSO", "WT_DMSO"],
        ["Rad21KO_DMSO-LPS", "WT_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "WT_BD1-LPS"],
        ["Rad21KO_BD2-LPS", "WT_BD2-LPS"],
        ["WT_DMSO", "WT_DMSO-LPS"],
        ["WT_BD1-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_DMSO-LPS"],
        ["WT_BD2-LPS", "WT_BD1-LPS"],
        ["Rad21KO_DMSO", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD2-LPS", "Rad21KO_DMSO-LPS"],
        ["Rad21KO_BD1-LPS", "Rad21KO_BD2-LPS"],
        ])

CSV.write("$AnalysisName/"*"$ehnname"*"_BFs.csv", BFs_gene)
CSV.write("$AnalysisName/"*"$ehnname"*"_BFs_TEST.csv", TEST)
   title("Rad21KO")

BFs_gene_sub = BFs_gene[BFs_gene[!, :Genotype].== "Rad21KO", :]

Seaborn.stripplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["red" ],order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
Seaborn.boxplot(data = Pandas.DataFrame(BFs_gene_sub), y = "BF", x = "Timepoint", hue = "Genotype", dodge = true, palette = ["red"],order = ["DMSO", "DMSO-LPS","BD1-LPS","BD2-LPS"])
ylabel("Enh burst freq.")
xlabel("Treatment")
plt.tight_layout()

h1,h2,h3, h4 = 0.2, 0.24, 0.28, 0.25

ii = 0
h = h1
xy = [-0+ii, 1+ii]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[9, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")
h = h2
xy = [1, 2]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[10, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h3
xy = [1, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[11, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ii=+1
h = h4
xy = [2, 3]; xy2 = [Statistics.mean(xy) , h+0.005]
plt.plot(xy, [h, h], c = "black")
pval = TEST[12, :padj]
plt.annotate(NoLongerProblems.transform_pvalue_in_stars(pval), xy = xy2, ha= "center")

ylim(0, ylimit);legend_removal();pretty_axes2();line075black();squareplot();xticks(rotation=90)

end
# Out:
# SystemError: opening file "/Users/irr15/OneDrive - Imperial College London/Code_Paper/FiguresBD/HiddenCode.jl": No such file or directory
#
# Stacktrace:
#   [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#     @ Base ./error.jl:168
#   [2] #systemerror#62
#     @ ./error.jl:167 [inlined]
#   [3] systemerror
#     @ ./error.jl:167 [inlined]
#   [4] open(fname::String; lock::Bool, read::Nothing, write::Nothing, create::Nothing, truncate::Nothing, append::Nothing)
#     @ Base ./iostream.jl:293
#   [5] open
#     @ ./iostream.jl:282 [inlined]
#   [6] open(f::Base.var"#326#327"{String}, args::String; kwargs::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Base ./io.jl:328
#   [7] open
#     @ ./io.jl:328 [inlined]
#   [8] read
#     @ ./io.jl:434 [inlined]
#   [9] _include(mapexpr::Function, mod::Module, _path::String)
#     @ Base ./loading.jl:1166
#  [10] include(fname::String)
#     @ Base.MainInclude ./client.jl:444
# ...
