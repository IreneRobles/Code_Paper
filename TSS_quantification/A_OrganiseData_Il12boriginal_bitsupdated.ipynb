# %%
include("StandardCode.jl")
# Out:
# bs_bf (generic function with 1 method)

# %%
function TSSs.TSS_raw_quant(t2, tss_folder, image_folder, n; xy = 0.189, zx = 0.5)
    
    images_pat = intersect(TSSs.get_image_patterns(t2), TSSs.get_image_patterns(tss_folder))
    
    p = Progress(length(images_pat), 1)

    dfs = []

    for a in 1:length(images_pat)
        next!(p)
        

        pat = images_pat[a]

        # Get all the TSS in the images
        a = TSSs.find_outline(tss_folder, pat)
        tss = TSSs.cell_tss_dict(a)
        tss = TSSs.meassure_tss(tss, imagesfolder, pat, n, xy = xy, zx = zx)
    
        df = TSSs.analysis_singlechannel(tss; image = pat,  tss_name = :TSS2)
        push!(dfs, df)

    end
    
    d = TSSs.join_in_all_common_columns(dfs...)
    return d
    
end

function normalise_avgdot(df, genename, expn, typeprobe, ibidislide; root = pwd(), genefolder = "Gene")
    dot1_r1 = TSSs.int_brightest_pixel(TSSs.read_tiff_as_gray(root * typeprobe *"/_mRNA_AVG_ns.tif").*255; radious = 1)
    dot1_r2 = TSSs.int_brightest_pixel(TSSs.read_tiff_as_gray(root * typeprobe * "/_mRNA_AVG_ns.tif").*255; radious = 2)
    dot1_r3 = TSSs.int_brightest_pixel(TSSs.read_tiff_as_gray(root * typeprobe * "/_mRNA_AVG_ns.tif").*255; radious = 3)

    df[!,:TSS1_r1] = df[!,:locus1_int1_TSS2] ./ dot1_r1
    df[!,:TSS1_r2] = df[!,:locus1_int2_TSS2] ./ dot1_r2
    df[!,:TSS1_r3] = df[!,:locus1_int3_TSS2] ./ dot1_r3
    df[!,:TSS2_r1] = df[!,:locus2_int1_TSS2] ./ dot1_r1
    df[!,:TSS2_r2] = df[!,:locus2_int2_TSS2] ./ dot1_r2
    df[!,:TSS2_r3] = df[!,:locus2_int3_TSS2] ./ dot1_r3
    
    CSV.write("TSS_avgdot/"*genename*"_exp"*"$expn"*".csv", df)
    ibidislide[!,:Well] = [split(ii, " (")[1] for ii in ibidislide[!,:Well]]
    exp1 = CSV.read("TSS_avgdot/"*gene*"_exp"*"$expn"*".csv", DataFrame)
    CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_TSS.csv", exp1)
    fq_dir1 = root1*typeprobe*"/"
    fq1 = FQ_summary_MATURE(fq_dir1)
    CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ.csv", fq1)
end
# Out:
# normalise_avgdot (generic function with 1 method)

# %%
ROOT1 = "/Volumes/lymphdev\$/IreneR/Confocal/il12b_intron_exon/Exp1/"
ROOT2 = "/Volumes/lymphdev\$/IreneR/Confocal/il12b_intron_exon/Exp2/"
ROOT3 = "/Volumes/lymphdev\$/IreneR/Confocal/il12b_intron_exon/Exp4/"
ROOT4 = "/Volumes/lymphdev\$/IreneR/Confocal/il12b_intron_exon/Exp6/"
# Out:
# "/Volumes/lymphdev\$/IreneR/Confocal/il12b_intron_exon/Exp6/"

# %%
root1 = ROOT1
expn = 1
gene = "Il12b_intron_original"
tss_c4 = root1 * "Segmentation_type4/_FQ_outline/_TS_detect"
imagesfolder = root1 * "/tiff3D"
images_pat = TSSs.get_image_patterns(tss_c4)
d = TSSs.TSS_raw_quant(tss_c4, tss_c4, imagesfolder, 3; xy = 0.189, zx = 0.5)
CSV.write("TSS_raw/"*gene*"_exp"*"$expn"*".csv", d)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 1:02:24
# "TSS_raw/Il12b_intron_original_exp1.csv"

# %%
root1 = ROOT2
expn = 2
gene = "Il12b_intron_original"
tss_c4 = root1 * "Segmentation_type4/_FQ_outline/_TS_detect"
imagesfolder = root1 * "/tiff3D"
images_pat = TSSs.get_image_patterns(tss_c4)
d = TSSs.TSS_raw_quant(tss_c4, tss_c4, imagesfolder, 3; xy = 0.189, zx = 0.5)
CSV.write("TSS_raw/"*gene*"_exp"*"$expn"*".csv", d)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 1:09:58
# "TSS_raw/Il12b_intron_original_exp2.csv"

# %%
root1 = ROOT3
expn = 3
gene = "Il12b_intron_original"
tss_c4 = root1 * "Segmentation_type4/_FQ_outline/_TS_detect"
imagesfolder = root1 * "/tiff3D"
images_pat = TSSs.get_image_patterns(tss_c4)
d = TSSs.TSS_raw_quant(tss_c4, tss_c4, imagesfolder, 3; xy = 0.189, zx = 0.5)
CSV.write("TSS_raw/"*gene*"_exp"*"$expn"*".csv", d)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:12:10
# "TSS_raw/Il12b_intron_original_exp3.csv"

# %%
root1 = ROOT4
expn = 4
gene = "Il12b_intron_original"
tss_c4 = root1 * "Segmentation_type4/_FQ_outline/_TS_detect"
imagesfolder = root1 * "/tiff3D"
images_pat = TSSs.get_image_patterns(tss_c4)
d = TSSs.TSS_raw_quant(tss_c4, tss_c4, imagesfolder, 3; xy = 0.189, zx = 0.5)
CSV.write("TSS_raw/"*gene*"_exp"*"$expn"*".csv", d)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:31:53
# "TSS_raw/Il12b_intron_original_exp4.csv"

# %%
folder = "Il12b_original"

root1 = ROOT1
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_1.csv", DataFrame)
expn = 1
gene = "Il12b_intron_original"
typeprobe = "type4"
tss1 = CSV.read("TSS_raw/"*gene*"_exp"*"$expn"*".csv", DataFrame)
normalise_avgdot(tss1, gene, expn, typeprobe, exp; root = root1, genefolder = folder)

root1 = ROOT2
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_2.csv", DataFrame)
expn = 2
gene = "Il12b_intron_original"
typeprobe = "type4"
tss1 = CSV.read("TSS_raw/"*gene*"_exp"*"$expn"*".csv", DataFrame)
normalise_avgdot(tss1, gene, expn, typeprobe, exp; root = root1, genefolder = folder)

root1 = ROOT3
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_3.csv", DataFrame)
expn = 3
gene = "Il12b_intron_original"
typeprobe = "type4"
tss1 = CSV.read("TSS_raw/"*gene*"_exp"*"$expn"*".csv", DataFrame)
normalise_avgdot(tss1, gene, expn, typeprobe, exp; root = root1, genefolder = folder)

root1 = ROOT4
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_4.csv", DataFrame)
expn = 4
gene = "Il12b_intron_original"
typeprobe = "type4"
tss1 = CSV.read("TSS_raw/"*gene*"_exp"*"$expn"*".csv", DataFrame)
normalise_avgdot(tss1, gene, expn, typeprobe, exp; root = root1, genefolder = folder)
# Out:
# WARNING: both Pandas and DataFrames export "DataFrame"; uses of it in module NoLongerProblems_Pandas must be qualified
# "Il12b_original/Il12b_intron_original_exp4_FQ.csv"

# %%
genefolder = "Il12b_original"
root1 = ROOT1
expn = 1
gene = "Il12b_intron_original"
typeprobe = "type6"
fq_dir1 = root1*typeprobe*"/"
fq1 = FQ_summary_MATURE(fq_dir1)
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", fq1)

root1 = ROOT2
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_2.csv", DataFrame)
expn = 2
gene = "Il12b_intron_original"
typeprobe = "type6"
fq_dir1 = root1*typeprobe*"/"
fq1 = FQ_summary_MATURE(fq_dir1)
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", fq1)

root1 = ROOT3
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_3.csv", DataFrame)
expn = 3
gene = "Il12b_intron_original"
typeprobe = "type6"
fq_dir1 = root1*typeprobe*"/"
fq1 = FQ_summary_MATURE(fq_dir1)
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", fq1)

root1 = ROOT4
exp = CSV.read("IbidiChambers/IbidiChamberSlide_Il12boriginal_4.csv", DataFrame)
expn = 4
gene = "Il12b_intron_original"
typeprobe = "type6"
fq_dir1 = root1*typeprobe*"/"
fq1 = FQ_summary_MATURE(fq_dir1)
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", fq1)
# Out:
# "Il12b_original/Il12b_intron_original_exp4_FQ_mature.csv"

# %%
function timepoint(ii)
    if occursin("U 0", ii) 
        return "0"
    elseif occursin("U 1", ii) 
        return "60"
    elseif occursin("U 2", ii) 
        return "90"
    elseif occursin("U 3", ii) || occursin("FL120", ii)
        return "120"
    else 
        "120"
    end
end


function genotype(ii)
    if occursin("V 0", ii) 
        return "WT"
    elseif occursin("V 1", ii) 
        return "Rad21KO" 
     elseif occursin("FL120", ii)
        return "Rad21KO"
    else 
        "unknown"
    end
end
# Out:
# genotype (generic function with 1 method)

# %%
folder = "Il12b_original"

expn = 1
gene = "Il12b_intron_original"
tss1 = CSV.read(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", DataFrames.DataFrame)
tss1[!,:Timepoint] = [ timepoint(ii) for ii in tss1[!,:Image]]
tss1[!,:Genotype] = [ genotype(ii) for ii in tss1[!,:Image]]
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_CP.csv", tss1[!,["Genotype","Timepoint","Image_Cell"]])

expn = 2
gene = "Il12b_intron_original"
tss1 = CSV.read(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", DataFrames.DataFrame)
tss1[!,:Timepoint] = [ timepoint(ii) for ii in tss1[!,:Image]]
tss1[!,:Genotype] = [ genotype(ii) for ii in tss1[!,:Image]]
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_CP.csv", tss1[!,["Genotype","Timepoint","Image_Cell"]])

expn = 3
gene = "Il12b_intron_original"
tss1 = CSV.read(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", DataFrames.DataFrame)
tss1[!,:Timepoint] = [ timepoint(ii) for ii in tss1[!,:Image]]
tss1[!,:Genotype] = [ genotype(ii) for ii in tss1[!,:Image]]
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_CP.csv", tss1[!,["Genotype","Timepoint","Image_Cell"]])

expn = 4
gene = "Il12b_intron_original"
tss1 = CSV.read(genefolder*"/"*gene*"_exp"*"$expn"*"_FQ_mature.csv", DataFrames.DataFrame)
tss1[!,:Timepoint] = [ timepoint(ii) for ii in tss1[!,:Image]]
tss1[!,:Genotype] = [ genotype(ii) for ii in tss1[!,:Image]]
CSV.write(genefolder*"/"*gene*"_exp"*"$expn"*"_CP.csv", tss1[!,["Genotype","Timepoint","Image_Cell"]])
# Out:
# "Il12b_original/Il12b_intron_original_exp4_CP.csv"

# %%
expn = 4
gene = "Il12b_intron_original"
tss1 = CSV.read(genefolder*"/"*gene*"_exp"*"$expn"*"_TSS.csv", DataFrames.DataFrame)
tss1[!,:Timepoint] = [ timepoint(ii) for ii in tss1[!,:Image]]
tss1[!,:Genotype] = [ genotype(ii) for ii in tss1[!,:Image]]
pd = Pandas.DataFrame(tss1[tss1[!,:TSS2_r2].> 0, :])

#Seaborn.boxplot(data = pd, y = "TSS2_r2", x= "Timepoint")

#ylim(0,25)
# Out:
#           Cell  ... Genotype
# 0   Cell_CP_14  ...       WT
# 1    Cell_CP_8  ...       WT
# 2    Cell_CP_3  ...       WT
# 3   Cell_CP_53  ...       WT
# 4   Cell_CP_16  ...       WT
# 5    Cell_CP_3  ...       WT
# 6   Cell_CP_19  ...       WT
# 7   Cell_CP_62  ...       WT
# 8   Cell_CP_30  ...       WT
# 9   Cell_CP_14  ...       WT
# 10   Cell_CP_2  ...       WT
# 11  Cell_CP_54  ...       WT
# 12  Cell_CP_32  ...       WT
# 13   Cell_CP_2  ...       WT
# 14  Cell_CP_74  ...       WT
# 15   Cell_CP_5  ...       WT
# 16   Cell_CP_2  ...       WT
# 17   Cell_CP_3  ...       WT
# 18  Cell_CP_41  ...       WT
# 19  Cell_CP_66  ...       WT
# 20  Cell_CP_81  ...       WT
# 21  Cell_CP_39  ...       WT
# 22  Cell_CP_33  ...       WT
# 23  Cell_CP_20  ...       WT
# 24  Cell_CP_38  ...  Rad21KO
# 25  Cell_CP_32  ...       WT
# 26  Cell_CP_53  ...       WT
# 27  Cell_CP_39  ...       WT
# 28  Cell_CP_64  ...       WT
# 29  Cell_CP_40  ...       WT
# 30  Cell_CP_25  ...       WT
# 31  Cell_CP_50  ...       WT
# 32  Cell_CP_75  ...       WT
# 33  Cell_CP_61  ...       WT
# 34  Cell_CP_55  ...       WT
# 35  Cell_CP_36  ...       WT
# 36  Cell_CP_21  ...       WT
# 37  Cell_CP_38  ...       WT
# 38  Cell_CP_46  ...       WT
# 39  Cell_CP_20  ...       WT
# 40  Cell_CP_22  ...       WT
# 41  Cell_CP_52  ...       WT
# 42   Cell_CP_3  ...       WT
# 43  Cell_CP_90  ...       WT
# 44  Cell_CP_35  ...       WT
#
# [45 rows x 27 columns]
