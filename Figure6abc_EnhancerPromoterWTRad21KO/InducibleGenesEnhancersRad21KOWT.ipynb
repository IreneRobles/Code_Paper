# %%
ENV["Code"] = "../../Code"

for ii in readdir(ENV["Code"])
push!(LOAD_PATH, string(ENV["Code"],"/", ii));
end

include("../Code/HiddenCode_BSBF.jl")
include("../Code/meanmRNAcounts_BSBF.jl")
include("../Code/Functions.jl")
include("../Code/CalculateBF.jl")
include("GetCoocs.jl")

# %%
include("PlotBurstFrequencies.jl")
plt.tight_layout()
# Out:
# Figure(PyObject <Figure size 1500x800 with 15 Axes>)

# %%
plotgeneenhancerbf("Il12b_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Il12b_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.872
# p = 0.00473
# Rad21KO
# r = 0.53
# p = 0.176
# All
# r = 0.416
# p = 0.109                     Df   Sum Sq  Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.001728 0.001728    9.59 0.009246 **
# Genotype              1 0.003629 0.003629   20.14 0.000742 ***
# BF_Enhancer:Genotype  1 0.002467 0.002467   13.69 0.003033 **
# Residuals            12 0.002162 0.000180
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df   Sum Sq  Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.001728 0.001728    9.59 0.009246 **
# Genotype              1 0.003629 0.003629   20.14 0.000742 ***
# BF_Enhancer:Genotype  1 0.002467 0.002467   13.69 0.003033 **
# Residuals            12 0.002162 0.000180
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Prdm1_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Prdm1_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.807
# p = 0.0521
# Rad21KO
# r = -0.923
# p = 0.00869
# All
# r = -0.106
# p = 0.742                     Df    Sum Sq   Mean Sq F value  Pr(>F)
# BF_Enhancer           1 0.0000112 0.0000112   0.343 0.57446
# Genotype              1 0.0000100 0.0000100   0.305 0.59608
# BF_Enhancer:Genotype  1 0.0007094 0.0007094  21.710 0.00162 **
# Residuals             8 0.0002614 0.0000327
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df    Sum Sq   Mean Sq F value  Pr(>F)
# BF_Enhancer           1 0.0000112 0.0000112   0.343 0.57446
# Genotype              1 0.0000100 0.0000100   0.305 0.59608
# BF_Enhancer:Genotype  1 0.0007094 0.0007094  21.710 0.00162 **
# Residuals             8 0.0002614 0.0000327
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Egr2_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Egr2_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.847
# p = 0.153
# Rad21KO
# r = 0.724
# p = 0.276
# All
# r = 0.828
# p = 0.0112                     Df  Sum Sq Mean Sq F value Pr(>F)
# BF_Enhancer           1 0.12134 0.12134  18.347 0.0128 *
# Genotype              1 0.01032 0.01032   1.560 0.2797
# BF_Enhancer:Genotype  1 0.01908 0.01908   2.885 0.1647
# Residuals             4 0.02646 0.00661
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df  Sum Sq Mean Sq F value Pr(>F)
# BF_Enhancer           1 0.12134 0.12134  18.347 0.0128 *
# Genotype              1 0.01032 0.01032   1.560 0.2797
# BF_Enhancer:Genotype  1 0.01908 0.01908   2.885 0.1647
# Residuals             4 0.02646 0.00661
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Peli1_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Peli1_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.954
# p = 0.000242
# Rad21KO
# r = 0.74
# p = 0.0358
# All
# r = 0.716
# p = 0.00183                     Df Sum Sq Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.5136  0.5136   45.14 2.14e-05 ***
# Genotype              1 0.1583  0.1583   13.91  0.00287 **
# BF_Enhancer:Genotype  1 0.1946  0.1946   17.10  0.00138 **
# Residuals            12 0.1365  0.0114
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df Sum Sq Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.5136  0.5136   45.14 2.14e-05 ***
# Genotype              1 0.1583  0.1583   13.91  0.00287 **
# BF_Enhancer:Genotype  1 0.1946  0.1946   17.10  0.00138 **
# Residuals            12 0.1365  0.0114
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Ifnb1forL2", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Ifnb1forL2
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.329
# p = 0.426
# Rad21KO
# r = 0.444
# p = 0.27
# All
# r = 0.405
# p = 0.12                     Df   Sum Sq   Mean Sq F value Pr(>F)
# BF_Enhancer           1 0.000817 0.0008172   2.398  0.147
# Genotype              1 0.000063 0.0000635   0.186  0.674
# BF_Enhancer:Genotype  1 0.000009 0.0000092   0.027  0.872
# Residuals            12 0.004089 0.0003407
# RObject{VecSxp}
#                      Df   Sum Sq   Mean Sq F value Pr(>F)
# BF_Enhancer           1 0.000817 0.0008172   2.398  0.147
# Genotype              1 0.000063 0.0000635   0.186  0.674
# BF_Enhancer:Genotype  1 0.000009 0.0000092   0.027  0.872
# Residuals            12 0.004089 0.0003407

# %%
import Pkg; Pkg.status()
# Out:
#       Status `~/.julia/environments/v1.6/Project.toml`
#   [7e6ae17a] BioSequences v2.0.5
#   [336ed68f] CSV v0.9.11
#   [8f4d0f93] Conda v1.5.2
#   [a93c6f00] DataFrames v1.2.2
#   [31c24e10] Distributions v0.25.28
#   [c2308a5c] FASTX v1.2.0
#   [09f84164] HypothesisTests v0.10.6
#   [7073ff75] IJulia v1.23.2
#   [916415d5] Images v0.24.1
#   [f8716d33] MultipleTesting v0.5.0
#   [92933f4c] ProgressMeter v1.7.1
#   [d330b81b] PyPlot v2.10.0
#   [6f49c342] RCall v0.13.12
#   [d2ef9438] Seaborn v1.0.0
#   [2913bbd2] StatsBase v0.33.13
