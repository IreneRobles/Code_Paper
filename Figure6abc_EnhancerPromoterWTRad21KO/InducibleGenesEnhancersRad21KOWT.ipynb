# %%
ENV["Code"] = "../../Code"

for ii in readdir(ENV["Code"])
push!(LOAD_PATH, string(ENV["Code"],"/", ii));
end

include("../Code/HiddenCode_BSBF.jl")
include("../Code/meanmRNAcounts_BSBF.jl")
include("../Code/Functions.jl")
include("../Code/CalculateBF.jl")
include("GetCoocs.jl")
# Out:
# "../SourceData/Fig6abc_EnhancerGeneBF.csv"

# %%
include("PlotBurstFrequencies.jl")
plt.tight_layout()
# Out:
# ┌ Warning: RCall.jl: Loading required package: grid
# └ @ RCall /Users/irr15/.julia/packages/RCall/iMDW2/src/io.jl:160
# ┌ Warning: RCall.jl:
# │ Attaching package: ‘DescTools’
# │
# │ The following objects are masked from ‘package:psych’:
# │
# │     AUC, ICC, SD
# │
# └ @ RCall /Users/irr15/.julia/packages/RCall/iMDW2/src/io.jl:160
# ┌ Warning: RCall.jl:
# │ Attaching package: ‘rcompanion’
# │
# │ The following object is masked from ‘package:psych’:
# │
# │     phi
# │
# └ @ RCall /Users/irr15/.julia/packages/RCall/iMDW2/src/io.jl:160
# ┌ Warning: RCall.jl:
# │ Attaching package: ‘dplyr’
# │
# │ The following objects are masked from ‘package:stats’:
# │
# │     filter, lag
# │
# │ The following objects are masked from ‘package:base’:
# │
# │     intersect, setdiff, setequal, union
# │
# └ @ RCall /Users/irr15/.julia/packages/RCall/iMDW2/src/io.jl:160
# Figure(PyObject <Figure size 1500x800 with 14 Axes>)

# %%
plotgeneenhancerbf("Il12b_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Il12b_intron
# WT
# r = 0.875
# p = 0.00446
# Rad21KO
# r = 0.527
# p = 0.18
# All
# r = 0.416
# p = 0.109                     Df   Sum Sq  Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.001693 0.001693   9.819 0.008634 **
# Genotype              1 0.003580 0.003580  20.766 0.000658 ***
# BF_Enhancer:Genotype  1 0.002419 0.002419  14.029 0.002794 **
# Residuals            12 0.002069 0.000172
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# RObject{VecSxp}
#                      Df   Sum Sq  Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.001693 0.001693   9.819 0.008634 **
# Genotype              1 0.003580 0.003580  20.766 0.000658 ***
# BF_Enhancer:Genotype  1 0.002419 0.002419  14.029 0.002794 **
# Residuals            12 0.002069 0.000172
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Prdm1_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Prdm1_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.815
# p = 0.0483
# Rad21KO
# r = -0.905
# p = 0.013
# All
# r = -0.085
# p = 0.792                     Df    Sum Sq   Mean Sq F value  Pr(>F)
# BF_Enhancer           1 0.0000069 0.0000069   0.216 0.65429
# Genotype              1 0.0000088 0.0000088   0.274 0.61456
# BF_Enhancer:Genotype  1 0.0006802 0.0006802  21.179 0.00175 **
# Residuals             8 0.0002569 0.0000321
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df    Sum Sq   Mean Sq F value  Pr(>F)
# BF_Enhancer           1 0.0000069 0.0000069   0.216 0.65429
# Genotype              1 0.0000088 0.0000088   0.274 0.61456
# BF_Enhancer:Genotype  1 0.0006802 0.0006802  21.179 0.00175 **
# Residuals             8 0.0002569 0.0000321
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Egr2_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Egr2_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.824
# p = 0.0119
# Rad21KO
# r = 0.747
# p = 0.0333
# All
# r = 0.802
# p = 0.000186                     Df  Sum Sq Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.19166 0.19166  42.155 2.97e-05 ***
# Genotype              1 0.03082 0.03082   6.779   0.0231 *
# BF_Enhancer:Genotype  1 0.02097 0.02097   4.611   0.0529 .
# Residuals            12 0.05456 0.00455
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df  Sum Sq Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.19166 0.19166  42.155 2.97e-05 ***
# Genotype              1 0.03082 0.03082   6.779   0.0231 *
# BF_Enhancer:Genotype  1 0.02097 0.02097   4.611   0.0529 .
# Residuals            12 0.05456 0.00455
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
plotgeneenhancerbf("Peli1_intron", tb, xy = [0.01, 0.05], onlyLPS = false)
# Out:
# Peli1_intron
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# WT
# r = 0.951
# p = 0.000282
# Rad21KO
# r = 0.729
# p = 0.0403
# All
# r = 0.706
# p = 0.00226                     Df Sum Sq Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.4943  0.4943   42.09 2.99e-05 ***
# Genotype              1 0.1609  0.1609   13.70  0.00303 **
# BF_Enhancer:Genotype  1 0.1966  0.1966   16.74  0.00149 **
# Residuals            12 0.1409  0.0117
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# RObject{VecSxp}
#                      Df Sum Sq Mean Sq F value   Pr(>F)
# BF_Enhancer           1 0.4943  0.4943   42.09 2.99e-05 ***
# Genotype              1 0.1609  0.1609   13.70  0.00303 **
# BF_Enhancer:Genotype  1 0.1966  0.1966   16.74  0.00149 **
# Residuals            12 0.1409  0.0117
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
import Pkg; Pkg.status()
# Out:
#       Status `~/.julia/environments/v1.6/Project.toml`
#   [7e6ae17a] BioSequences v2.0.5
#   [336ed68f] CSV v0.9.11
#   [8f4d0f93] Conda v1.5.2
#   [a93c6f00] DataFrames v1.2.2
#   [31c24e10] Distributions v0.25.28
#   [c2308a5c] FASTX v1.2.0
#   [09f84164] HypothesisTests v0.10.6
#   [7073ff75] IJulia v1.23.2
#   [916415d5] Images v0.24.1
#   [96684042] InformationMeasures v0.3.1
#   [10e44e05] MATLAB v0.8.2
#   [f8716d33] MultipleTesting v0.5.0
#   [92933f4c] ProgressMeter v1.7.1
#   [438e738f] PyCall v1.92.5
#   [d330b81b] PyPlot v2.10.0
#   [6f49c342] RCall v0.13.12
#   [d2ef9438] Seaborn v1.0.0
#   [2913bbd2] StatsBase v0.33.13
