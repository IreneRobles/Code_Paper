# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/Users/irr15/Library/R/3.4/library’
# (as ‘lib’ is unspecified)
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# ggplot2  3.1.0  3.3.3             FALSE
# installing the source package ‘ggplot2’

# %%
library(devtools)
library(ggplot2)
library(GGally)
# Out:
# Warning message:
# “package ‘devtools’ was built under R version 3.4.4”

# %%
set1<-read.csv("cormatset1.csv")

ggcorr(data = set1,label= 1)

ggsave("cormatset1.svg", width =2.5, height = 2.5)
# Out:
# plot without title

# %%
set1<-read.csv("cormatset2.csv")

ggcorr(data = set1,label= 1)

ggsave("cormatset2.svg", width =2.5, height = 2.5)
# Out:
# plot without title
