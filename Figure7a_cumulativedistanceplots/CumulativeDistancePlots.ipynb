# %% [markdown]
# # Cumulative distance plots between genes and enhancers
#
# P value = Kolgomorov-Smirnov test

# %% [markdown]
# ## Rad21KO vs WT

# %%
include("../Figure3f_distances/HiddenCode.jl")
include("Figures.jl")
figure(figsize = (15, 7))
suff = "200um_noz"
limit = 10
subplot(2,4,1)
show_distances2("../CompleteSets/linkedlocus/","Egr2_intron","Egr2_enh",suff, limit = limit)
subplot(2,4,2)
show_distances2("../CompleteSets/linkedlocus/","Prdm1_intron","Prdm1_enh",suff,  limit = limit)
subplot(2,4,3)
show_distances2("../CompleteSets/linkedlocus/","Il12b_intron","HSS1",suff, limit = limit, limit_enh =0)
subplot(2,4,4)
show_distances2("../CompleteSets/linkedlocus/","Peli1_intron","Enh",suff, limit = limit)
limit = 1
subplot(2,4,5)
show_distances2("../CompleteSets/linkedlocus/","Egr2_intron","Egr2_enh",suff, limit = limit)
subplot(2,4,6)
show_distances2("../CompleteSets/linkedlocus/","Prdm1_intron","Prdm1_enh",suff,  limit = limit)
subplot(2,4,7)
show_distances2("../CompleteSets/linkedlocus/","Il12b_intron","HSS1",suff, limit = limit, limit_enh =0)
subplot(2,4,8)
show_distances2("../CompleteSets/linkedlocus/","Peli1_intron","Enh",suff, limit = limit)

legend()
plt.tight_layout()
savefigwithtext("GeneEnhdistancesCumplot___link"*suff*".svg")
# Out:
# WARNING: replacing module TSSs.
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# ...

# %% [markdown]
# ## BD inihibitor comparison
# ### limit = 10 um

# %%
figure(figsize = (15, 7))

suff = "200um_noz"
limit = 10
show_distances_BD("../CompleteSets/linkedlocus/","Il12b_intron_BD","HSS1_BD",
    suff, limit = limit, limit_enh =0,
    subplots = [(2,4,1), (2,4,2)]
)
show_distances_BD("../CompleteSets/linkedlocus/","Egr2_intron_BD","Egr2_enh_BD",
    suff, limit = limit, limit_enh =1,
    subplots = [(2,4,3), (2,4,4)]
)

savefigwithtext("GeneEnhdistancesCumplotBDInhibitor___link"*suff*"__limit"*string(limit)*".svg")
# Out:
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# Figure(PyObject <Figure size 1500x700 with 4 Axes>)
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ...

# %% [markdown]
# ### limit = 1 um

# %%
figure(figsize = (15, 7))
limit = 1
show_distances_BD("../CompleteSets/linkedlocus/","Il12b_intron_BD","HSS1_BD",
    suff, limit = limit, limit_enh =0,
    subplots = [(2,4,5), (2,4,6)]
)
show_distances_BD("../CompleteSets/linkedlocus/","Egr2_intron_BD","Egr2_enh_BD",
    suff, limit = limit, limit_enh =1,
    subplots = [(2,4,7), (2,4,8)]
)
savefigwithtext("GeneEnhdistancesCumplotBDInhibitor___link"*suff*"__limit"*string(limit)*".svg")
# Out:
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# Figure(PyObject <Figure size 1500x700 with 4 Axes>)
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ...

# %%
import Pkg; Pkg.status()
# Out:
#       Status `~/.julia/environments/v1.6/Project.toml`
#   [336ed68f] CSV v0.9.11
#   [a93c6f00] DataFrames v0.22.7
#   [31c24e10] Distributions v0.23.12
#   [c2308a5c] FASTX v1.2.0
#   [53c48c17] FixedPointNumbers v0.8.4
#   [09f84164] HypothesisTests v0.10.2
#   [7073ff75] IJulia v1.23.2
#   [6a3955dd] ImageFiltering v0.6.21
#   [6218d12a] ImageMagick v1.2.2
#   [86fae568] ImageView v0.10.13
#   [916415d5] Images v0.23.3
#   [4138dd39] JLD v0.12.3
#   [093fc24a] LightGraphs v1.3.5
#   [10e44e05] MATLAB v0.8.0
#   [f8716d33] MultipleTesting v0.4.1
#   [eadc2687] Pandas v1.4.0
#   [91a5bcdd] Plots v1.21.2
#   [92933f4c] ProgressMeter v1.5.0
#   [438e738f] PyCall v1.92.2
#   [d330b81b] PyPlot v2.9.0
#   [6f49c342] RCall v0.13.10
#   [3646fa90] ScikitLearn v0.6.3
#   [d2ef9438] Seaborn v0.4.1
#   [2913bbd2] StatsBase v0.33.10

# %%
figure(figsize = (15, 7))
limit = 5
show_distances_BD("../CompleteSets/linkedlocus/","Il12b_intron_BD","HSS1_BD",
    suff, limit = limit, limit_enh =0,
    subplots = [(2,4,5), (2,4,6)]
)
show_distances_BD("../CompleteSets/linkedlocus/","Egr2_intron_BD","Egr2_enh_BD",
    suff, limit = limit, limit_enh =1,
    subplots = [(2,4,7), (2,4,8)]
)
savefigwithtext("GeneEnhdistancesCumplotBDInhibitor___link"*suff*"__limit"*string(limit)*".svg")
# Out:
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# Figure(PyObject <Figure size 1500x700 with 4 Axes>)
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ┌ Warning: This test is inaccurate with ties
# └ @ HypothesisTests /Users/irene/.julia/packages/HypothesisTests/40Llk/src/kolmogorov_smirnov.jl:167
# ...

# %%
tb = linked_data("../CompleteSets/linkedlocus/","Egr2_intron_BD","Egr2_enh_BD", suff)

sum(tb[!,:Genotype].=="Rad21KO")
# Out:
# 11764
