# %% [markdown]
# # scRNAseq

# %%
ENV["Code"] = "../../Code"
for folder in readdir(ENV["Code"]); push!(LOAD_PATH, normpath(ENV["Code"], folder));end
using SingleCellExperimentJulia
using GeneSets
using Seaborn
using PyPlot
using PyCall
using Statistics
using NoLongerProblems_Pandas
import Pandas
using MultipleTesting
using HypothesisTests 
using DataFrames
using Bhatt2012
using CSV
using GeneSets
using ProgressMeter
using PrettyPlotting
using SergiSingleCell2
using ScikitLearn
@sk_import linear_model: LogisticRegression

function SingleCellExperimentJulia.fit_single_cell_logistic_regression(singlecelldata; splitdataby = :Sample, assay = "CPM", fitparameter = "mu")
    cells = singlecelldata.colData[!,:CellID]
    b0 = []
    b1 = []
    p = Progress(length(cells))
    
    for cell in cells
        cell_index = find_cell_index(cell, singlecelldata)
        condition = find_cell_condition(cell, splitdataby, singlecelldata)
        genes__mus_in_condition = Array{Float64, 2}(singlecelldata.rowData[:, [Symbol(string(condition, "__", fitparameter))]])
         expression_cell_bool = Array{Float64,1}([i > 0 for i in singlecelldata.assays[assay][:, cell_index]])
        # fit each cell to a logistic regression
        model_ = LogisticRegression(penalty = "l2").fit(genes__mus_in_condition, expression_cell_bool)
        next!(p)
        push!(b0, model_.intercept_[1])
        push!(b1, model_.coef_[1])
    end
    
    singlecelldata.colData[!,:B0] = b0
    singlecelldata.colData[!,:B1] = b1
    
    return singlecelldata
    
end

function squareplot()
    ax = gca()
    ax.set_aspect(1.0/ax.get_data_ratio(), adjustable="box")

end

function savefigwithtext(figname)
        
    py"""
import matplotlib as mpl

new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
mpl.rcParams.update(new_rc_params)
import matplotlib.pyplot as plt
plt.savefig($figname)
"""

end
# Out:
# ┌ Info: Installing pyqt package to avoid buggy tkagg backend.
# └ @ PyPlot /Users/irene/.julia/packages/PyPlot/XHEG0/src/init.jl:118
# savefigwithtext (generic function with 1 method)

# %%
# Perform the log(CPM + 1) transformation (Counts per million reads in each cell)
# Load the data
cd = SergiSingleCell2.SergiSingleCell_counts()
coldata = SergiSingleCell2.SergiSingleCell_colData();
coldata[!,:RowName] = [replace(ii, "."=> "_") for ii in coldata[!,:RowName]]

for ii in names(cd)
    stri = Symbol(replace("$ii", "."=> "_"))
    rename!(cd, ii => stri)
end
# Object that store Single cell Data
sce = SingleCellExperiment(cd, coldata)
sce = SingleCellExperimentJulia.get_cells_with_this_characteristics(["WT", "RAD21"], :Genotype, sce)
sce = SingleCellExperimentJulia.select_expressed_genes(sce, min_cells_expressing_gene = 20)
sce = SingleCellExperimentJulia.cpm_transform(sce)
sce = SingleCellExperimentJulia.ln_cpm_plus1_transform(sce)
sce = SingleCellExperimentJulia.fit_mu_std_alpha(sce, splitdataby = :Sample, assay = "CPM")
sce = SingleCellExperimentJulia.fit_single_cell_logistic_regression(sce, assay = "CPM")
bhattgenes = Bhatt2012.inducible_genes_figure3()[!,:GeneSymbol];
sce = SingleCellExperimentJulia.Shalek2014_module_score(collect(bhattgenes), sce,fitparameter = "mu", modulescore_name = :BhattGenesScore, untreated_pattern = "UT",comparedtothissample = "WT", assay = "CPM")
# Out:
# /Users/irene/anaconda3/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:46
# SingleCellExperiment
# Cells = 1362, Genes = 17938
# assays : CPM lnCPMplus1
# colData : RowName Genotype Sample Timepoint CellID TotalCounts TotalGenes B0 B1 BhattGenesScore
# rowData : GeneID TotalCounts TotalCells FractionCells WT_UT__mu WT_UT__std WT_UT__alpha WT_UT__averagepop WT_UT__var RAD21_UT__mu RAD21_UT__std RAD21_UT__alpha RAD21_UT__averagepop RAD21_UT__var WT_2H__mu WT_2H__std WT_2H__alpha WT_2H__averagepop WT_2H__var RAD21_2H__mu RAD21_2H__std RAD21_2H__alpha RAD21_2H__averagepop RAD21_2H__var WT_8H__mu WT_8H__std WT_8H__alpha WT_8H__averagepop WT_8H__var RAD21_8H__mu RAD21_8H__std RAD21_8H__alpha RAD21_8H__averagepop RAD21_8H__var All__mu All__std All__alpha All__averagepop All__var
# reducedDimNames :

# %%
sce = SingleCellExperimentJulia.fit_mu_std_alpha(sce, splitdataby = :Sample, assay = "lnCPMplus1")


bhattgenes= DataFrames.DataFrame(
    "GeneID" => Bhatt2012.inducible_genes_figure3()[!,:GeneSymbol], 
    "Class"=>Bhatt2012.inducible_genes_figure3()[!,:Class]
    );
sceBhatt = innerjoin(sce.rowData, bhattgenes,on = :GeneID)
sceBhatt[!,:Class] = [replace(replace(ii, "A1"=>"A1+2"), "A2"=>"A1+2") for ii in  sceBhatt[!,:Class]]
#sceBhatt[!,:Class] = [replace(ii, r"B|C"=>"B+C") for ii in  sceBhatt[!,:Class]]
#sceBhatt[!,:Class] = [replace(ii, r"D|E|F"=>"D+E+F") for ii in  sceBhatt[!,:Class]]
# Out:
# 497-element Vector{String}:
#  "E"
#  "E"
#  "F"
#  "F"
#  "F"
#  "C"
#  "C"
#  "F"
#  "D"
#  "C"
#  "C"
#  "D"
#  "D"
#  ⋮
#  "E"
#  "F"
#  "E"
#  "E"
#  "C"
#  "E"
#  "F"
#  "D"
#  "F"
#  "F"
#  "A1+2"
#  "D"

# %%
p1s = []
p1as = []

for class in sort!(unique(sceBhatt[!,"Class"]))
    println("Class $class")
    println("ln CPM plus 1 in expressing cells")
   
    println("WT UT vs WT 2H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_UT__mu"]], [ii for ii in sub[!,"WT_2H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    
      println("WT 2H vs WT 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_2H__mu"]], [ii for ii in sub[!,"WT_8H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    
    println("WT UT vs WT 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_UT__mu"]], [ii for ii in sub[!,"WT_8H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    
  
    
    println("Fraction Expressing cells")
   println("WT UT vs WT 2H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_UT__alpha"]], [ii for ii in sub[!,"WT_2H__alpha"]])
    println(t)
    p1a = pvalue(t)  
   push!(p1as, p1a)
    
      println("WT 2H vs WT 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_2H__alpha"]], [ii for ii in sub[!,"WT_8H__alpha"]])
    println(t)
    p1a = pvalue(t)  
    push!(p1as, p1a)
    
    println("WT UT vs WT 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_UT__alpha"]], [ii for ii in sub[!,"WT_8H__alpha"]])
    println(t)
    p1a = pvalue(t)  
    push!(p1as, p1a)
     
end
# Out:
# Class A1+2
# ln CPM plus 1 in expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.00501264
#     95% confidence interval: (-0.1094, 0.0845)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.7787
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1029.0
#     rank sums:                   [1029.0, 1116.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-43.5, 153.024)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.110671
#     95% confidence interval: (0.0159, 0.2071)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0226
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1422.0
#     rank sums:                   [1422.0, 723.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (349.5, 153.024)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0925871
#     95% confidence interval: (-0.0305, 0.1494)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1700
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1283.0
#     rank sums:                   [1283.0, 862.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (210.5, 153.024)
#
# Fraction Expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.188734
#     95% confidence interval: (-0.2607, -0.1708)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-11
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 11.0
#     rank sums:                   [11.0, 2134.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1061.5, 153.024)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.110351
#     95% confidence interval: (0.0929, 0.1549)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 2001.0
#     rank sums:                   [2001.0, 144.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (928.5, 153.024)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0416294
#     95% confidence interval: (-0.1086, -0.0331)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 280.0
#     rank sums:                   [280.0, 1865.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-792.5, 153.023)
#
# Class B
# ln CPM plus 1 in expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0636501
#     95% confidence interval: (0.0154, 0.1813)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0203
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 911.0
#     rank sums:                   [911.0, 415.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (248.0, 106.684)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.020456
#     95% confidence interval: (-0.1091, 0.049)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.3559
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 564.0
#     rank sums:                   [564.0, 762.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-99.0, 106.684)
#
# WT UT vs WT 8H
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0
#     95% confidence interval: (-0.0271, 0.1024)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.2991
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 718.0
#     rank sums:                   [718.0, 507.0]
#     adjustment for ties:         0.0
#
# Fraction Expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.110384
#     95% confidence interval: (-0.1516, -0.1024)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-09
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 0.0
#     rank sums:                   [0.0, 1326.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-663.0, 106.684)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0510021
#     95% confidence interval: (0.0326, 0.0805)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 1089.0
#     rank sums:                   [1089.0, 237.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (426.0, 106.684)
#
# WT UT vs WT 8H
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0482393
#     95% confidence interval: (-0.1003, -0.0375)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-07
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 101.0
#     rank sums:                   [101.0, 1124.0]
#     adjustment for ties:         0.0
#
# Class C
# ln CPM plus 1 in expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.209445
#     95% confidence interval: (-0.5171, -0.1946)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 635.0
#     rank sums:                   [635.0, 3020.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1192.5, 228.219)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.14455
#     95% confidence interval: (-0.2107, 0.0041)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.0601
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 1398.0
#     rank sums:                   [1398.0, 2257.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-429.5, 228.219)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.328957
#     95% confidence interval: (-0.6079, -0.326)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-11
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 268.0
#     rank sums:                   [268.0, 3387.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1559.5, 228.219)
#
# Fraction Expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.337472
#     95% confidence interval: (-0.421, -0.3124)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-14
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 4.0
#     rank sums:                   [4.0, 3651.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1823.5, 228.219)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0
#     95% confidence interval: (-0.0459, 0.0379)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.8773
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 1708.5
#     rank sums:                   [1708.5, 1777.5]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-34.5, 220.258)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.366508
#     95% confidence interval: (-0.4216, -0.3167)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-14
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 0.0
#     rank sums:                   [0.0, 3655.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1827.5, 228.219)
#
# Class D
# ln CPM plus 1 in expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0247133
#     95% confidence interval: (-0.0607, 0.1234)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.5067
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 2310.0
#     rank sums:                   [2310.0, 1968.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (171.0, 256.812)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.434689
#     95% confidence interval: (-0.629, -0.397)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-14
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 112.0
#     rank sums:                   [112.0, 4166.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-2027.0, 256.812)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.258447
#     95% confidence interval: (-0.6084, -0.2347)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 664.0
#     rank sums:                   [664.0, 3614.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1475.0, 256.812)
#
# Fraction Expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.123622
#     95% confidence interval: (-0.1798, -0.1203)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-15
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 12.0
#     rank sums:                   [12.0, 4266.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-2127.0, 256.812)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0773399
#     95% confidence interval: (-0.1489, -0.0706)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 651.0
#     rank sums:                   [651.0, 3627.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-1488.0, 256.812)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.24061
#     95% confidence interval: (-0.3379, -0.23)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-15
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 10.0
#     rank sums:                   [10.0, 4268.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-2129.0, 256.812)
#
# Class E
# ln CPM plus 1 in expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.220708
#     95% confidence interval: (0.2046, 0.4657)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-10
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 4672.0
#     rank sums:                   [4672.0, 684.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (1994.0, 303.959)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.686875
#     95% confidence interval: (-0.9014, -0.6416)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-18
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 1.0
#     rank sums:                   [1.0, 5564.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-2781.5, 312.812)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.261626
#     95% confidence interval: (-0.4241, -0.2303)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-10
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 709.0
#     rank sums:                   [709.0, 4856.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-2073.5, 312.812)
#
# Fraction Expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0399514
#     95% confidence interval: (-0.0639, -0.0388)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-15
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 169.0
#     rank sums:                   [169.0, 5187.0]
#     adjustment for ties:         30.0
#     normal approximation (μ, σ): (-2509.0, 303.958)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.169449
#     95% confidence interval: (-0.2575, -0.1666)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 121.0
#     rank sums:                   [121.0, 5444.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-2661.5, 312.812)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.230012
#     95% confidence interval: (-0.3336, -0.2226)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-18
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 2.0
#     rank sums:                   [2.0, 5563.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-2780.5, 312.812)
#
# Class F
# ln CPM plus 1 in expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.357386
#     95% confidence interval: (0.3604, 0.5378)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 4817.0
#     rank sums:                   [4817.0, 34.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (2391.5, 282.201)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.56405
#     95% confidence interval: (-0.7075, -0.5337)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 23.0
#     rank sums:                   [23.0, 4927.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-2452.0, 286.509)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.142806
#     95% confidence interval: (-0.1866, -0.0667)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 1340.0
#     rank sums:                   [1340.0, 3610.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1135.0, 286.509)
#
# Fraction Expressing cells
# WT UT vs WT 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0213704
#     95% confidence interval: (-0.0316, -0.0146)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 982.0
#     rank sums:                   [982.0, 3869.0]
#     adjustment for ties:         24.0
#     normal approximation (μ, σ): (-1443.5, 282.2)
#
# WT 2H vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.189469
#     95% confidence interval: (-0.2252, -0.1544)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-15
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 123.0
#     rank sums:                   [123.0, 4827.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-2352.0, 286.509)
#
# WT UT vs WT 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.20564
#     95% confidence interval: (-0.2476, -0.1797)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-17
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 13.0
#     rank sums:                   [13.0, 4937.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-2462.0, 286.509)

# %%
figure(figsize = (20, 10))


subplot(1,2,1)
y = "Fraction of cells \n with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_UT__alpha", "WT_2H__alpha", "WT_8H__alpha"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Time after LPS (h)",showfliers = false,  palette = "Blues")
pretty_axes2()

title("WT")

hs = [  1, 1.1, 1.2,1, 1.1, 1.2, 1.1, 1.2, 1.3, 1, 1.1, 1.2, 1, 1.1, 1.2, 1.1, 1.2, 1.3, 1, 1.1, 1.2]
ps = adjust([ii for ii in p1as], Bonferroni())

ii = 0

for pp in 1:6
    ii+=1
    plot([pp-1.25, pp-1.05], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-1.05]), hs[ii]+0.05], va = "center", ha = "center")

    ii+=1
    plot([pp-0.95, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-0.95, pp-0.75]), hs[ii]+0.05], va = "center", ha = "center")

    ii+=1
    plot([pp-1.25, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-0.75]), hs[ii]+0.05], va = "center", ha = "center")

    
    

end

ylim(0, 1.5)
squareplot()

legend_removal()

subplot(1,2,2)
y = "ln(CPM + 1) \n cells with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_UT__mu", "WT_2H__mu", "WT_8H__mu"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Time after LPS (h)",showfliers = false,  palette = "Blues")
pretty_axes2()



hs = [ 8.5, 8.75, 9, 8.5, 8.75, 9, 9.1, 9.35, 9.65, 9, 9.25, 9.5, 8.5, 8.75, 9, 9.1, 9.35, 9.65, 9, 9.25, 9.5]
ps = adjust([ii for ii in p1s], Bonferroni())

ii = 0

for pp in 1:6
    ii+=1
    plot([pp-1.25, pp-1.05], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-1.05]), hs[ii]+0.09], va = "center", ha = "center")

    ii+=1
    plot([pp-0.95, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-0.95, pp-0.75]), hs[ii]+0.09], va = "center", ha = "center")

    ii+=1
    plot([pp-1.25, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-0.75]), hs[ii]+0.09], va = "center", ha = "center")

    
    

end

squareplot()
legend_out_of_plot()

plt.tight_layout()

title("WT")

savefigwithtext("BhattClass_WT_6class.svg")
# Out:
# Figure(PyObject <Figure size 2000x1000 with 2 Axes>)

# %%
p1s
# Out:
# 18-element Vector{Any}:
#  0.7787086814442427
#  0.02256664322419851
#  0.1699587008528829
#  0.0203444993703206
#  0.35585792828293233
#  0.29912101938019126
#  1.759889871838816e-7
#  0.06013857200156025
#  8.422578291011557e-12
#  0.5067483638274757
#  2.9982121534738345e-15
#  9.381389058220705e-9
#  5.436886152814282e-11
#  6.092860533239155e-19
#  3.4260798772300664e-11
#  2.3978480068595508e-17
#  1.164009384277379e-17
#  7.50333693379422e-5
