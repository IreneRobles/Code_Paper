# %% [markdown]
# # scRNAseq

# %%
ENV["Code"] = "../../Code"
for folder in readdir(ENV["Code"]); push!(LOAD_PATH, normpath(ENV["Code"], folder));end
using SingleCellExperimentJulia
using GeneSets
using Seaborn
using PyPlot
using PyCall
using Statistics
using NoLongerProblems_Pandas
import Pandas
using MultipleTesting
using HypothesisTests 
using DataFrames
using Bhatt2012
using CSV
using GeneSets
using ProgressMeter
using PrettyPlotting
using SergiSingleCell2
using ScikitLearn
@sk_import linear_model: LogisticRegression

function SingleCellExperimentJulia.fit_single_cell_logistic_regression(singlecelldata; splitdataby = :Sample, assay = "CPM", fitparameter = "mu")
    cells = singlecelldata.colData[!,:CellID]
    b0 = []
    b1 = []
    p = Progress(length(cells))
    
    for cell in cells
        cell_index = find_cell_index(cell, singlecelldata)
        condition = find_cell_condition(cell, splitdataby, singlecelldata)
        genes__mus_in_condition = Array{Float64, 2}(singlecelldata.rowData[:, [Symbol(string(condition, "__", fitparameter))]])
         expression_cell_bool = Array{Float64,1}([i > 0 for i in singlecelldata.assays[assay][:, cell_index]])
        # fit each cell to a logistic regression
        model_ = LogisticRegression(penalty = "l2").fit(genes__mus_in_condition, expression_cell_bool)
        next!(p)
        push!(b0, model_.intercept_[1])
        push!(b1, model_.coef_[1])
    end
    
    singlecelldata.colData[!,:B0] = b0
    singlecelldata.colData[!,:B1] = b1
    
    return singlecelldata
    
end

function squareplot()
    ax = gca()
    ax.set_aspect(1.0/ax.get_data_ratio(), adjustable="box")

end

function savefigwithtext(figname)
        
    py"""
import matplotlib as mpl

new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
mpl.rcParams.update(new_rc_params)
import matplotlib.pyplot as plt
plt.savefig($figname)
"""

end
# Out:
# ┌ Info: Installing pyqt package to avoid buggy tkagg backend.
# └ @ PyPlot /Users/irene/.julia/packages/PyPlot/XHEG0/src/init.jl:118
# savefigwithtext (generic function with 1 method)

# %%
# Perform the log(CPM + 1) transformation (Counts per million reads in each cell)
# Load the data
cd = SergiSingleCell2.SergiSingleCell_counts()
coldata = SergiSingleCell2.SergiSingleCell_colData();
coldata[!,:RowName] = [replace(ii, "."=> "_") for ii in coldata[!,:RowName]]

for ii in names(cd)
    stri = Symbol(replace("$ii", "."=> "_"))
    rename!(cd, ii => stri)
end
# Object that store Single cell Data
sce = SingleCellExperiment(cd, coldata)
sce = SingleCellExperimentJulia.get_cells_with_this_characteristics(["WT", "RAD21"], :Genotype, sce)
sce = SingleCellExperimentJulia.select_expressed_genes(sce, min_cells_expressing_gene = 20)
sce = SingleCellExperimentJulia.cpm_transform(sce)
sce = SingleCellExperimentJulia.ln_cpm_plus1_transform(sce)
sce = SingleCellExperimentJulia.fit_mu_std_alpha(sce, splitdataby = :Sample, assay = "CPM")
sce = SingleCellExperimentJulia.fit_single_cell_logistic_regression(sce, assay = "CPM")
bhattgenes = Bhatt2012.inducible_genes_figure3()[!,:GeneSymbol];
sce = SingleCellExperimentJulia.Shalek2014_module_score(collect(bhattgenes), sce,fitparameter = "mu", modulescore_name = :BhattGenesScore, untreated_pattern = "UT",comparedtothissample = "WT", assay = "CPM")
# Out:
# /Users/irene/anaconda3/lib/python2.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:44
# SingleCellExperiment
# Cells = 1362, Genes = 17938
# assays : CPM lnCPMplus1
# colData : RowName Genotype Sample Timepoint CellID TotalCounts TotalGenes B0 B1 BhattGenesScore
# rowData : GeneID TotalCounts TotalCells FractionCells WT_UT__mu WT_UT__std WT_UT__alpha WT_UT__averagepop WT_UT__var RAD21_UT__mu RAD21_UT__std RAD21_UT__alpha RAD21_UT__averagepop RAD21_UT__var WT_2H__mu WT_2H__std WT_2H__alpha WT_2H__averagepop WT_2H__var RAD21_2H__mu RAD21_2H__std RAD21_2H__alpha RAD21_2H__averagepop RAD21_2H__var WT_8H__mu WT_8H__std WT_8H__alpha WT_8H__averagepop WT_8H__var RAD21_8H__mu RAD21_8H__std RAD21_8H__alpha RAD21_8H__averagepop RAD21_8H__var All__mu All__std All__alpha All__averagepop All__var
# reducedDimNames :

# %%
sce = SingleCellExperimentJulia.fit_mu_std_alpha(sce, splitdataby = :Sample, assay = "lnCPMplus1")


bhattgenes= DataFrames.DataFrame(
    "GeneID" => Bhatt2012.inducible_genes_figure3()[!,:GeneSymbol], 
    "Class"=>Bhatt2012.inducible_genes_figure3()[!,:Class]
    );
sceBhatt = innerjoin(sce.rowData, bhattgenes,on = :GeneID)
sceBhatt[!,:Class] = [replace(replace(ii, "A1"=>"A1+2"), "A2"=>"A1+2") for ii in  sceBhatt[!,:Class]]
#sceBhatt[!,:Class] = [replace(ii, r"B|C"=>"B+C") for ii in  sceBhatt[!,:Class]]
#sceBhatt[!,:Class] = [replace(ii, r"D|E|F"=>"D+E+F") for ii in  sceBhatt[!,:Class]]
# Out:
# 497-element Vector{String}:
#  "E"
#  "E"
#  "F"
#  "F"
#  "F"
#  "C"
#  "C"
#  "F"
#  "D"
#  "C"
#  "C"
#  "D"
#  "D"
#  ⋮
#  "E"
#  "F"
#  "E"
#  "E"
#  "C"
#  "E"
#  "F"
#  "D"
#  "F"
#  "F"
#  "A1+2"
#  "D"

# %%
p1s = []
p1as = []

for class in sort!(unique(sceBhatt[!,"Class"]))
    println("Class $class")
    println("ln CPM plus 1 in expressing cells")
   
    println("RAD21 UT vs RAD21 2H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"RAD21_UT__mu"]], [ii for ii in sub[!,"RAD21_2H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    
      println("RAD21 2H vs RAD21 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"RAD21_2H__mu"]], [ii for ii in sub[!,"RAD21_8H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    
    println("RAD21 UT vs RAD21 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"RAD21_UT__mu"]], [ii for ii in sub[!,"RAD21_8H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    
  
    
    println("Fraction Expressing cells")
   println("RAD21 UT vs RAD21 2H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"RAD21_UT__alpha"]], [ii for ii in sub[!,"RAD21_2H__alpha"]])
    println(t)
    p1a = pvalue(t)  
   push!(p1as, p1a)
    
      println("RAD21 2H vs RAD21 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"RAD21_2H__alpha"]], [ii for ii in sub[!,"RAD21_8H__alpha"]])
    println(t)
    p1a = pvalue(t)  
    push!(p1as, p1a)
    
    println("RAD21 UT vs RAD21 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"RAD21_UT__alpha"]], [ii for ii in sub[!,"RAD21_8H__alpha"]])
    println(t)
    p1a = pvalue(t)  
    push!(p1as, p1a)
     
end
# Out:
# Class A1+2
# ln CPM plus 1 in expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.157711
#     95% confidence interval: (-0.2645, -0.0705)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0009
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 562.0
#     rank sums:                   [562.0, 1583.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-510.5, 153.024)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.312139
#     95% confidence interval: (0.2473, 0.4117)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 2002.0
#     rank sums:                   [2002.0, 143.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (929.5, 153.024)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.123074
#     95% confidence interval: (0.0377, 0.2572)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0081
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1478.0
#     rank sums:                   [1478.0, 667.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (405.5, 153.024)
#
# Fraction Expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.144086
#     95% confidence interval: (-0.2013, -0.1232)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-11
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 4.0
#     rank sums:                   [4.0, 2141.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-1068.5, 153.023)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.062452
#     95% confidence interval: (0.0565, 0.1113)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-07
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1918.0
#     rank sums:                   [1918.0, 227.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (845.5, 153.024)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0410384
#     95% confidence interval: (-0.1059, -0.0469)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 167.0
#     rank sums:                   [167.0, 1978.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-905.5, 153.023)
#
# Class B
# ln CPM plus 1 in expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.043693
#     95% confidence interval: (-0.0792, 0.0319)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.3608
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 565.0
#     rank sums:                   [565.0, 761.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-98.0, 106.684)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.119211
#     95% confidence interval: (0.0283, 0.1656)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0074
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 949.0
#     rank sums:                   [949.0, 377.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (286.0, 106.684)
#
# RAD21 UT vs RAD21 8H
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.10819
#     95% confidence interval: (0.0124, 0.157)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0236
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 871.0
#     rank sums:                   [871.0, 404.0]
#     adjustment for ties:         0.0
#
# Fraction Expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0750299
#     95% confidence interval: (-0.1143, -0.0618)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 43.0
#     rank sums:                   [43.0, 1283.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-620.0, 106.684)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.00835253
#     95% confidence interval: (-0.0423, 0.0043)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1186
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 496.0
#     rank sums:                   [496.0, 830.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-167.0, 106.684)
#
# RAD21 UT vs RAD21 8H
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0805556
#     95% confidence interval: (-0.1531, -0.0777)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-12
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 19.0
#     rank sums:                   [19.0, 1256.0]
#     adjustment for ties:         0.0
#
# Class C
# ln CPM plus 1 in expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.352215
#     95% confidence interval: (-0.5729, -0.3166)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-10
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 347.0
#     rank sums:                   [347.0, 3308.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1480.5, 228.219)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0546495
#     95% confidence interval: (-0.0327, 0.1826)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1744
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 2138.0
#     rank sums:                   [2138.0, 1517.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (310.5, 228.219)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.296512
#     95% confidence interval: (-0.5148, -0.221)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-07
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 560.0
#     rank sums:                   [560.0, 3095.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1267.5, 228.219)
#
# Fraction Expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.323417
#     95% confidence interval: (-0.4296, -0.2988)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-14
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 5.0
#     rank sums:                   [5.0, 3650.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1822.5, 228.219)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0181932
#     95% confidence interval: (-0.0558, 0.0327)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.4887
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 1669.0
#     rank sums:                   [1669.0, 1986.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-158.5, 228.219)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.369147
#     95% confidence interval: (-0.4427, -0.3185)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-14
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 0.0
#     rank sums:                   [0.0, 3655.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1827.5, 228.219)
#
# Class D
# ln CPM plus 1 in expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0864982
#     95% confidence interval: (-0.1715, -0.0206)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0177
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 1493.0
#     rank sums:                   [1493.0, 2693.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-600.0, 252.659)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0576767
#     95% confidence interval: (-0.1631, 0.0001)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.0508
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 1637.0
#     rank sums:                   [1637.0, 2641.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-502.0, 256.812)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0688301
#     95% confidence interval: (-0.3043, -0.0275)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0125
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 1497.0
#     rank sums:                   [1497.0, 2781.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-642.0, 256.812)
#
# Fraction Expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0750896
#     95% confidence interval: (-0.1192, -0.072)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-15
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 52.0
#     rank sums:                   [52.0, 4134.0]
#     adjustment for ties:         18.0
#     normal approximation (μ, σ): (-2041.0, 252.658)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0641321
#     95% confidence interval: (-0.135, -0.0689)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-10
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 463.0
#     rank sums:                   [463.0, 3815.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-1676.0, 256.812)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.164517
#     95% confidence interval: (-0.2606, -0.1582)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-15
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 10.0
#     rank sums:                   [10.0, 4268.0]
#     adjustment for ties:         12.0
#     normal approximation (μ, σ): (-2129.0, 256.812)
#
# Class E
# ln CPM plus 1 in expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0420606
#     95% confidence interval: (-0.0241, 0.1169)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.2031
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 3123.0
#     rank sums:                   [3123.0, 2337.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (393.0, 308.375)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0798853
#     95% confidence interval: (-0.2382, -0.0615)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0004
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 1668.0
#     rank sums:                   [1668.0, 3897.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-1114.5, 312.812)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0121195
#     95% confidence interval: (-0.1653, 0.0436)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.2929
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 2453.0
#     rank sums:                   [2453.0, 3112.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-329.5, 312.812)
#
# Fraction Expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0344086
#     95% confidence interval: (-0.0547, -0.0317)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-12
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 525.5
#     rank sums:                   [525.5, 4934.5]
#     adjustment for ties:         102.0
#     normal approximation (μ, σ): (-2204.5, 308.371)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.123176
#     95% confidence interval: (-0.1785, -0.11)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 174.0
#     rank sums:                   [174.0, 5391.0]
#     adjustment for ties:         12.0
#     normal approximation (μ, σ): (-2608.5, 312.811)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.146892
#     95% confidence interval: (-0.2418, -0.1522)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-18
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 0.0
#     rank sums:                   [0.0, 5565.0]
#     adjustment for ties:         12.0
#     normal approximation (μ, σ): (-2782.5, 312.811)
#
# Class F
# ln CPM plus 1 in expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.118777
#     95% confidence interval: (0.0535, 0.1613)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0004
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 3369.0
#     rank sums:                   [3369.0, 1384.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (992.5, 277.914)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.109663
#     95% confidence interval: (-0.1725, 0.0048)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.0672
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 1950.0
#     rank sums:                   [1950.0, 3000.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-525.0, 286.509)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0232063
#     95% confidence interval: (-0.0307, 0.1041)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.3007
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 2772.0
#     rank sums:                   [2772.0, 2178.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (297.0, 286.509)
#
# Fraction Expressing cells
# RAD21 UT vs RAD21 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.00872162
#     95% confidence interval: (-0.0191, -0.0048)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0008
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 1440.0
#     rank sums:                   [1440.0, 3313.0]
#     adjustment for ties:         36.0
#     normal approximation (μ, σ): (-936.5, 277.913)
#
# RAD21 2H vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.103447
#     95% confidence interval: (-0.1653, -0.1026)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 85.0
#     rank sums:                   [85.0, 4865.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-2390.0, 286.509)
#
# RAD21 UT vs RAD21 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.111045
#     95% confidence interval: (-0.1795, -0.114)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-17
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 10.0
#     rank sums:                   [10.0, 4940.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (-2465.0, 286.509)

# %%
figure(figsize = (20, 10))

subplot(1,2,1)
y = "Fraction of cells \n with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["RAD21_UT__alpha", "RAD21_2H__alpha", "RAD21_8H__alpha"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Time after LPS (h)",showfliers = false,  palette = "Reds")
pretty_axes2()

title("RAD21")

hs = [  1, 1.1, 1.2,1, 1.1, 1.2,  1.1, 1.2, 1.3, 1, 1.1, 1.2, 1, 1.1, 1.2, 1.1, 1.2, 1.3, 1, 1.1, 1.2]
ps = adjust([ii for ii in p1as], Bonferroni())

ii = 0

for pp in 1:6
    ii+=1
    plot([pp-1.25, pp-1.05], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-1.05]), hs[ii]+0.05], va = "center", ha = "center")

    ii+=1
    plot([pp-0.95, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-0.95, pp-0.75]), hs[ii]+0.05], va = "center", ha = "center")

    ii+=1
    plot([pp-1.25, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-0.75]), hs[ii]+0.05], va = "center", ha = "center")

    
    

end

ylim(0, 1.5)
squareplot()

legend_removal()

subplot(1,2,2)
y = "ln(CPM + 1) \n cells with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["RAD21_UT__mu", "RAD21_2H__mu", "RAD21_8H__mu"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Time after LPS (h)",showfliers = false,  palette = "Reds")
pretty_axes2()



hs = [ 8.5, 8.75, 9, 8.5, 8.75, 9,9.1, 9.35, 9.65, 9, 9.25, 9.5, 8.5, 8.75, 9, 9.1, 9.35, 9.65, 9, 9.25, 9.5]
ps = adjust([ii for ii in p1s], Bonferroni())

ii = 0

for pp in 1:6
    ii+=1
    plot([pp-1.25, pp-1.05], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-1.05]), hs[ii]+0.09], va = "center", ha = "center")

    ii+=1
    plot([pp-0.95, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-0.95, pp-0.75]), hs[ii]+0.09], va = "center", ha = "center")

    ii+=1
    plot([pp-1.25, pp-0.75], [hs[ii], hs[ii]], lw = 0.75, c= "black")
    annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [Statistics.mean([pp-1.25, pp-0.75]), hs[ii]+0.09], va = "center", ha = "center")

    
    

end

squareplot()
legend_out_of_plot()

plt.tight_layout()

title("RAD21")

savefigwithtext("BhattClass_RAD21_6class.svg")
# Out:
# Figure(PyObject <Figure size 2000x1000 with 2 Axes>)
