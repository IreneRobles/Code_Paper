# %% [markdown]
# # scRNAseq

# %%
ENV["Code"] = "../../Code"
for folder in readdir(ENV["Code"]); push!(LOAD_PATH, normpath(ENV["Code"], folder));end
using SingleCellExperimentJulia
using GeneSets
using Seaborn
using PyPlot
using PyCall
using NoLongerProblems_Pandas
import Pandas
using MultipleTesting
using HypothesisTests 
using DataFrames
using Bhatt2012
using CSV
using GeneSets
using ProgressMeter
using PrettyPlotting
using SergiSingleCell2
using ScikitLearn
@sk_import linear_model: LogisticRegression

function SingleCellExperimentJulia.fit_single_cell_logistic_regression(singlecelldata; splitdataby = :Sample, assay = "CPM", fitparameter = "mu")
    cells = singlecelldata.colData[!,:CellID]
    b0 = []
    b1 = []
    p = Progress(length(cells))
    
    for cell in cells
        cell_index = find_cell_index(cell, singlecelldata)
        condition = find_cell_condition(cell, splitdataby, singlecelldata)
        genes__mus_in_condition = Array{Float64, 2}(singlecelldata.rowData[:, [Symbol(string(condition, "__", fitparameter))]])
         expression_cell_bool = Array{Float64,1}([i > 0 for i in singlecelldata.assays[assay][:, cell_index]])
        # fit each cell to a logistic regression
        model_ = LogisticRegression(penalty = "l2").fit(genes__mus_in_condition, expression_cell_bool)
        next!(p)
        push!(b0, model_.intercept_[1])
        push!(b1, model_.coef_[1])
    end
    
    singlecelldata.colData[!,:B0] = b0
    singlecelldata.colData[!,:B1] = b1
    
    return singlecelldata
    
end

function squareplot()
    ax = gca()
    ax.set_aspect(1.0/ax.get_data_ratio(), adjustable="box")

end

function savefigwithtext(figname)
        
    py"""
import matplotlib as mpl

new_rc_params = {'text.usetex': False,
"svg.fonttype": 'none'
}
mpl.rcParams.update(new_rc_params)
import matplotlib.pyplot as plt
plt.savefig($figname)
"""

end
# Out:
# WARNING: redefinition of constant LogisticRegression. This may fail, cause incorrect answers, or produce other errors.
# savefigwithtext (generic function with 1 method)

# %%
# Perform the log(CPM + 1) transformation (Counts per million reads in each cell)
# Load the data
cd = SergiSingleCell2.SergiSingleCell_counts()
coldata = SergiSingleCell2.SergiSingleCell_colData();
coldata[!,:RowName] = [replace(ii, "."=> "_") for ii in coldata[!,:RowName]]

for ii in names(cd)
    stri = Symbol(replace("$ii", "."=> "_"))
    rename!(cd, ii => stri)
end
# Object that store Single cell Data
sce = SingleCellExperiment(cd, coldata)
sce = SingleCellExperimentJulia.get_cells_with_this_characteristics(["WT", "RAD21"], :Genotype, sce)
sce = SingleCellExperimentJulia.select_expressed_genes(sce, min_cells_expressing_gene = 20)
sce = SingleCellExperimentJulia.cpm_transform(sce)
sce = SingleCellExperimentJulia.ln_cpm_plus1_transform(sce)
sce = SingleCellExperimentJulia.fit_mu_std_alpha(sce, splitdataby = :Sample, assay = "CPM")
sce = SingleCellExperimentJulia.fit_single_cell_logistic_regression(sce, assay = "CPM")
bhattgenes = Bhatt2012.inducible_genes_figure3()[!,:GeneSymbol];
sce = SingleCellExperimentJulia.Shalek2014_module_score(collect(bhattgenes), sce,fitparameter = "mu", modulescore_name = :BhattGenesScore, untreated_pattern = "UT",comparedtothissample = "WT", assay = "CPM")
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:56
# SingleCellExperiment
# Cells = 1362, Genes = 17938
# assays : CPM lnCPMplus1
# colData : RowName Genotype Sample Timepoint CellID TotalCounts TotalGenes B0 B1 BhattGenesScore
# rowData : GeneID TotalCounts TotalCells FractionCells WT_UT__mu WT_UT__std WT_UT__alpha WT_UT__averagepop WT_UT__var RAD21_UT__mu RAD21_UT__std RAD21_UT__alpha RAD21_UT__averagepop RAD21_UT__var WT_2H__mu WT_2H__std WT_2H__alpha WT_2H__averagepop WT_2H__var RAD21_2H__mu RAD21_2H__std RAD21_2H__alpha RAD21_2H__averagepop RAD21_2H__var WT_8H__mu WT_8H__std WT_8H__alpha WT_8H__averagepop WT_8H__var RAD21_8H__mu RAD21_8H__std RAD21_8H__alpha RAD21_8H__averagepop RAD21_8H__var All__mu All__std All__alpha All__averagepop All__var
# reducedDimNames :

# %%
sce = SingleCellExperimentJulia.fit_mu_std_alpha(sce, splitdataby = :Sample, assay = "lnCPMplus1")


bhattgenes= DataFrames.DataFrame(
    "GeneID" => Bhatt2012.inducible_genes_figure3()[!,:GeneSymbol], 
    "Class"=>Bhatt2012.inducible_genes_figure3()[!,:Class]
    );
sceBhatt = innerjoin(sce.rowData, bhattgenes,on = :GeneID)
sceBhatt[!,:Class] = [replace(replace(ii, "A1"=>"A1+2"), "A2"=>"A1+2") for ii in  sceBhatt[!,:Class]]
# Out:
# 497-element Vector{String}:
#  "E"
#  "E"
#  "F"
#  "F"
#  "F"
#  "C"
#  "C"
#  "F"
#  "D"
#  "C"
#  "C"
#  "D"
#  "D"
#  ⋮
#  "E"
#  "F"
#  "E"
#  "E"
#  "C"
#  "E"
#  "F"
#  "D"
#  "F"
#  "F"
#  "A1+2"
#  "D"

# %%
p1s = []
p1as = []

for class in sort!(unique(sceBhatt[!,"Class"]))
    println("Class $class")
    println("ln CPM plus 1 in expressing cells")
    println("WT UT vs Rad21KO UT")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_UT__mu"]], [ii for ii in sub[!,"RAD21_UT__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    println("Fraction Expressing cells")
    println("WT UT vs Rad21KO UT")
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_UT__alpha"]], [ii for ii in sub[!,"RAD21_UT__alpha"]])
    println(t)
    p1a = pvalue(t)
     push!(p1as, p1a)
end
# Out:
# Class A1+2
# ln CPM plus 1 in expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.211447
#     95% confidence interval: (0.1204, 0.2496)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1689.0
#     rank sums:                   [1689.0, 391.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (649.0, 149.533)
#
# Fraction Expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.00658608
#     95% confidence interval: (0.0035, 0.0307)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0057
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1454.0
#     rank sums:                   [1454.0, 626.0]
#     adjustment for ties:         36.0
#     normal approximation (μ, σ): (414.0, 149.53)
#
# Class B
# ln CPM plus 1 in expressing cells
# WT UT vs Rad21KO UT
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.113796
#     95% confidence interval: (0.0824, 0.1816)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 1077.0
#     rank sums:                   [1077.0, 148.0]
#     adjustment for ties:         0.0
#
# Fraction Expressing cells
# WT UT vs Rad21KO UT
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.00946846
#     95% confidence interval: (0.0023, 0.0254)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0131
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 860.0
#     rank sums:                   [860.0, 365.0]
#     adjustment for ties:         0.0
#
# Class C
# ln CPM plus 1 in expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.177907
#     95% confidence interval: (0.1388, 0.2328)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 3044.0
#     rank sums:                   [3044.0, 442.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (1301.0, 220.258)
#
# Fraction Expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0266233
#     95% confidence interval: (0.0198, 0.0517)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 2824.0
#     rank sums:                   [2824.0, 662.0]
#     adjustment for ties:         24.0
#     normal approximation (μ, σ): (1081.0, 220.257)
#
# Class D
# ln CPM plus 1 in expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.138027
#     95% confidence interval: (0.0915, 0.2041)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-05
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 3001.0
#     rank sums:                   [3001.0, 827.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (1087.0, 236.273)
#
# Fraction Expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.00514489
#     95% confidence interval: (0.0033, 0.0235)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0021
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 2642.0
#     rank sums:                   [2642.0, 1186.0]
#     adjustment for ties:         42.0
#     normal approximation (μ, σ): (728.0, 236.271)
#
# Class E
# ln CPM plus 1 in expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.115582
#     95% confidence interval: (0.0997, 0.2198)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 4076.0
#     rank sums:                   [4076.0, 1075.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (1500.5, 295.191)
#
# Fraction Expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0167364
#     95% confidence interval: (0.0146, 0.0382)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-07
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 4194.0
#     rank sums:                   [4194.0, 957.0]
#     adjustment for ties:         36.0
#     normal approximation (μ, σ): (1618.5, 295.19)
#
# Class F
# ln CPM plus 1 in expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.216466
#     95% confidence interval: (0.1906, 0.2959)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-11
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 4436.0
#     rank sums:                   [4436.0, 415.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (2010.5, 282.201)
#
# Fraction Expressing cells
# WT UT vs Rad21KO UT
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0332713
#     95% confidence interval: (0.0303, 0.0581)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-11
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 4364.0
#     rank sums:                   [4364.0, 487.0]
#     adjustment for ties:         24.0
#     normal approximation (μ, σ): (1938.5, 282.2)

# %%
figure(figsize = (9, 6))


subplot(1,2,2)
y = "ln(CPM + 1) \n cells with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_UT__mu", "RAD21_UT__mu"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Genotype",showfliers = false,  palette = ["darkgray", "red"])
pretty_axes2()
hs = [ 8, 7.8, 8.25, 8.13, 8.23, 8.1]
ps = adjust([ii for ii in p1s], Bonferroni())
for ii in 1:length(ps)
plot([-0.25+ii-1, 0.25+ii-1], [hs[ii], hs[ii]], lw = 0.75, c= "black")
annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [ii-1, hs[ii]+0.09], va = "center", ha = "center")
end
 ylim(5, 10)
squareplot()
legend_removal()

title("Untreated")


subplot(1,2,1)
y = "Fraction of cells \n with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_UT__alpha", "RAD21_UT__alpha"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Genotype",showfliers = false,  palette = ["darkgray", "red"])
pretty_axes2()
hs = [ 0.43, 0.5, 0.8, 0.5, 0.6, 0.7]
ps = adjust([ii for ii in p1as], Bonferroni())
for ii in 1:length(p1as)
plot([-0.25+ii-1, 0.25+ii-1], [hs[ii], hs[ii]], lw = 0.75, c= "black")
annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [ii-1, hs[ii]+0.02], va = "center", ha = "center")
end
 ylim(0, 1.2)
squareplot()
legend_removal()

title("Untreated")

plt.tight_layout()

savefigwithtext("BhattClass_UT_6class.svg")
# Out:
# Figure(PyObject <Figure size 900x600 with 2 Axes>)

# %%
p1s = []
p1as = []

for class in sort!(unique(sceBhatt[!,"Class"]))
    println("Class $class")
    println("ln CPM plus 1 in expressing cells")
    println("WT 2H vs Rad21KO 2H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_2H__mu"]], [ii for ii in sub[!,"RAD21_2H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    println("Fraction Expressing cells")
    println("WT 2H vs Rad21KO 2H")
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_2H__alpha"]], [ii for ii in sub[!,"RAD21_2H__alpha"]])
    println(t)
    p1a = pvalue(t)
     push!(p1as, p1a)
end
# Out:
# Class A1+2
# ln CPM plus 1 in expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0709897
#     95% confidence interval: (-0.0105, 0.1306)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.0845
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1337.0
#     rank sums:                   [1337.0, 808.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (264.5, 153.024)
#
# Fraction Expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0483871
#     95% confidence interval: (0.0349, 0.0968)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1698.5
#     rank sums:                   [1698.5, 381.5]
#     adjustment for ties:         192.0
#     normal approximation (μ, σ): (658.5, 149.519)
#
# Class B
# ln CPM plus 1 in expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0430949
#     95% confidence interval: (-0.0211, 0.1011)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1786
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 807.0
#     rank sums:                   [807.0, 519.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (144.0, 106.684)
#
# Fraction Expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0376344
#     95% confidence interval: (0.0242, 0.0726)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 1052.0
#     rank sums:                   [1052.0, 223.0]
#     adjustment for ties:         222.0
#     normal approximation (μ, σ): (414.5, 103.569)
#
# Class C
# ln CPM plus 1 in expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0779133
#     95% confidence interval: (0.0509, 0.1706)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0002
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 2687.0
#     rank sums:                   [2687.0, 968.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (859.5, 228.219)
#
# Fraction Expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0268817
#     95% confidence interval: (0.0242, 0.0726)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-04
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 2581.0
#     rank sums:                   [2581.0, 740.0]
#     adjustment for ties:         426.0
#     normal approximation (μ, σ): (920.5, 212.371)
#
# Class D
# ln CPM plus 1 in expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0200331
#     95% confidence interval: (-0.0312, 0.1325)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.2106
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 2461.0
#     rank sums:                   [2461.0, 1817.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (322.0, 256.812)
#
# Fraction Expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0430108
#     95% confidence interval: (0.0403, 0.0833)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 3525.5
#     rank sums:                   [3525.5, 569.5]
#     adjustment for ties:         288.0
#     normal approximation (μ, σ): (1478.0, 248.516)
#
# Class E
# ln CPM plus 1 in expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0360429
#     95% confidence interval: (-0.1651, 0.0241)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1485
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 2330.0
#     rank sums:                   [2330.0, 3235.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-452.5, 312.812)
#
# Fraction Expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0322581
#     95% confidence interval: (0.0296, 0.0565)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-08
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 4352.0
#     rank sums:                   [4352.0, 799.0]
#     adjustment for ties:         618.0
#     normal approximation (μ, σ): (1776.5, 295.169)
#
# Class F
# ln CPM plus 1 in expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.000336541
#     95% confidence interval: (-0.179, 0.0309)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.1934
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 2058.0
#     rank sums:                   [2058.0, 2793.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (-367.5, 282.201)
#
# Fraction Expressing cells
# WT 2H vs Rad21KO 2H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0430108
#     95% confidence interval: (0.0403, 0.0699)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-12
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 4484.5
#     rank sums:                   [4484.5, 366.5]
#     adjustment for ties:         438.0
#     normal approximation (μ, σ): (2059.0, 282.185)

# %%
figure(figsize = (9, 6))


subplot(1,2,2)
y = "ln(CPM + 1) \n cells with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_2H__mu", "RAD21_2H__mu"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Genotype",showfliers = false,  palette = ["darkgray", "red"])
pretty_axes2()
hs = [8.5, 8.3, 9.7, 8.7, 8.4, 8.3]
ps = adjust([ii for ii in p1s], Bonferroni())
for ii in 1:length(hs)
plot([-0.25+ii-1, 0.25+ii-1], [hs[ii], hs[ii]], lw = 0.75, c= "black")
annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [ii-1, hs[ii]+0.09], va = "center", ha = "center")
end

squareplot()
legend_removal()
 ylim(5, 10)
title("2H LPS")


subplot(1,2,1)
y = "Fraction of cells \n with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_2H__alpha", "RAD21_2H__alpha"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Genotype",showfliers = false,  palette = ["darkgray", "red"])
pretty_axes2()
hs = [ 0.9, 1, 1.1, 1, 0.7, 0.6]
ps = adjust([ii for ii in p1as], Bonferroni())
for ii in 1:length(hs)
plot([-0.25+ii-1, 0.25+ii-1], [hs[ii], hs[ii]], lw = 0.75, c= "black")
annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [ii-1, hs[ii]+0.02], va = "center", ha = "center")
end
 ylim(0, 1.2)
squareplot()
legend_removal()

title("2H LPS")

plt.tight_layout()

savefigwithtext("BhattClass_2hLPS_6class.svg")
# Out:
# Figure(PyObject <Figure size 900x600 with 2 Axes>)

# %%
p1s = []
p1as = []

for class in sort!(unique(sceBhatt[!,"Class"]))
    println("Class $class")
    println("ln CPM plus 1 in expressing cells")
    println("WT 8H vs Rad21KO 8H")
    sub = sceBhatt[sceBhatt[!,"Class"].==class, :]
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_8H__mu"]], [ii for ii in sub[!,"RAD21_8H__mu"]])
    println(t)
    p1 = pvalue(t)  
    push!(p1s, p1)
    println("Fraction Expressing cells")
    println("WT 8H vs Rad21KO 8H")
    t = HypothesisTests.SignedRankTest([ii for ii in sub[!,"WT_8H__alpha"]], [ii for ii in sub[!,"RAD21_8H__alpha"]])
    println(t)
    p1a = pvalue(t)
     push!(p1as, p1a)
end
# Out:
# Class A1+2
# ln CPM plus 1 in expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.303883
#     95% confidence interval: (0.2278, 0.3851)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-06
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1875.0
#     rank sums:                   [1875.0, 270.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (802.5, 153.024)
#
# Fraction Expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.00983185
#     95% confidence interval: (0.0004, 0.0432)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0455
#
# Details:
#     number of observations:      65
#     Wilcoxon rank-sum statistic: 1379.0
#     rank sums:                   [1379.0, 766.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (306.5, 153.023)
#
# Class B
# ln CPM plus 1 in expressing cells
# WT 8H vs Rad21KO 8H
# Exact Wilcoxon signed rank test
# -------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.173765
#     95% confidence interval: (0.0821, 0.2326)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0002
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 973.0
#     rank sums:                   [973.0, 252.0]
#     adjustment for ties:         0.0
#
# Fraction Expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          -0.0120379
#     95% confidence interval: (-0.0564, 0.0011)
#
# Test summary:
#     outcome with 95% confidence: fail to reject h_0
#     two-sided p-value:           0.0588
#
# Details:
#     number of observations:      51
#     Wilcoxon rank-sum statistic: 422.0
#     rank sums:                   [422.0, 803.0]
#     adjustment for ties:         12.0
#     normal approximation (μ, σ): (-190.5, 100.529)
#
# Class C
# ln CPM plus 1 in expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.286153
#     95% confidence interval: (0.2165, 0.3622)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-09
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 3268.0
#     rank sums:                   [3268.0, 387.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (1440.5, 228.219)
#
# Fraction Expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0099187
#     95% confidence interval: (0.004, 0.0573)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           0.0213
#
# Details:
#     number of observations:      85
#     Wilcoxon rank-sum statistic: 2302.0
#     rank sums:                   [2302.0, 1268.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (517.0, 224.226)
#
# Class D
# ln CPM plus 1 in expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.36716
#     95% confidence interval: (0.3246, 0.4968)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-14
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 4155.0
#     rank sums:                   [4155.0, 123.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (2016.0, 256.812)
#
# Fraction Expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.052286
#     95% confidence interval: (0.0446, 0.0988)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-07
#
# Details:
#     number of observations:      92
#     Wilcoxon rank-sum statistic: 3451.0
#     rank sums:                   [3451.0, 644.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (1403.5, 248.528)
#
# Class E
# ln CPM plus 1 in expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.395632
#     95% confidence interval: (0.3761, 0.4794)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-18
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 5561.0
#     rank sums:                   [5561.0, 4.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (2778.5, 312.812)
#
# Fraction Expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.104398
#     95% confidence interval: (0.0848, 0.1416)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-12
#
# Details:
#     number of observations:      105
#     Wilcoxon rank-sum statistic: 4943.0
#     rank sums:                   [4943.0, 517.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (2213.0, 308.375)
#
# Class F
# ln CPM plus 1 in expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.423596
#     95% confidence interval: (0.3778, 0.471)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-16
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 4925.0
#     rank sums:                   [4925.0, 25.0]
#     adjustment for ties:         0.0
#     normal approximation (μ, σ): (2450.0, 286.509)
#
# Fraction Expressing cells
# WT 8H vs Rad21KO 8H
# Approximate Wilcoxon signed rank test
# -------------------------------------
# Population details:
#     parameter of interest:   Location parameter (pseudomedian)
#     value under h_0:         0
#     point estimate:          0.0821984
#     95% confidence interval: (0.081, 0.1337)
#
# Test summary:
#     outcome with 95% confidence: reject h_0
#     two-sided p-value:           <1e-12
#
# Details:
#     number of observations:      99
#     Wilcoxon rank-sum statistic: 4599.0
#     rank sums:                   [4599.0, 351.0]
#     adjustment for ties:         6.0
#     normal approximation (μ, σ): (2124.0, 286.509)

# %%
figure(figsize = (9, 6))


subplot(1,2,2)
y = "ln(CPM + 1) \n cells with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_8H__mu", "RAD21_8H__mu"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Genotype",showfliers = false,  palette = ["darkgray", "red"])
pretty_axes2()
hs = [ 8.5, 9, 9.7, 9.5,9.3, 9]
ps = adjust([ii for ii in p1s], Bonferroni())
for ii in 1:length(hs)
plot([-0.25+ii-1, 0.25+ii-1], [hs[ii], hs[ii]], lw = 0.75, c= "black")
annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [ii-1, hs[ii]+0.09], va = "center", ha = "center")
end
 ylim(5, 10)
squareplot()
legend_removal()

title("8H LPS")


subplot(1,2,1)
y = "Fraction of cells \n with transcripts detected"
pd = Pandas.DataFrame(sort!(sceBhatt, :Class))

pd = Pandas.melt(pd, value_vars  = ["WT_8H__alpha", "RAD21_8H__alpha"], value_name = y, id_vars = ["GeneID","Class"] )
pd["Time after LPS (h)"] = [replace(replace(replace(split(ii, "_")[2], "UT" => 0), "2H" => 2), "8H" => 8) for ii in pd["variable"]]
pd["Genotype"] = [replace(split(ii, "_")[1], "RAD21" =>"Rad21KO") for ii in pd["variable"]]

Seaborn.boxplot(data = pd, y = y, x = "Class",hue = "Genotype",showfliers = false,  palette = ["darkgray", "red"])
pretty_axes2()
hs = [0.9, 1, 1.1, 1.05, 1.1, 1.05]
ps = adjust([ii for ii in p1as], Bonferroni())
for ii in 1:length(hs)
plot([-0.25+ii-1, 0.25+ii-1], [hs[ii], hs[ii]], lw = 0.75, c= "black")
annotate("P = "*string(round(ps[ii], sigdigits = 2)),xy = [ii-1, hs[ii]+0.02], va = "center", ha = "center")
end
 ylim(0, 1.2)
squareplot()
legend_removal()

title("8H LPS")

plt.tight_layout()

savefigwithtext("BhattClass_8hLPS_6class.svg")
# Out:
# Figure(PyObject <Figure size 900x600 with 2 Axes>)
