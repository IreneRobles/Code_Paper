# %%
ENV["Code"] = "../../Code"
[push!(LOAD_PATH, string(ENV["Code"],"/", ii)) for ii in readdir(ENV["Code"])]
include("../Code/Create_MF_GeneClass_Table.jl")
include("Figure.jl")

tb1 = dropmissing!(Cuartero2018.GroseqDeseq("WT1__vs__WT0"))
de2 = dropmissing!(Cuartero2018.Cuartero2018Deseq("WT2_Minus_WTUT"))

figure_de_gro_cor(de2, tb1, "RNAseq WT 2h LPS vs WT UT", "GROseq WT 1h LPS vs WT UT")

import Pkg; Pkg.status()
# Out:
# RObject{VecSxp}
#
# 	Pearson's product-moment correlation
#
# data:  `#JL`$x and `#JL`$y
# t = 80.261, df = 4206, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.7655892 0.7894733
# sample estimates:
#       cor
# 0.7778119
#
# RObject{RealSxp}
# [1] 0
#
#       Status `~/.julia/environments/v1.6/Project.toml`
# Figure(PyObject <Figure size 748.625x500 with 1 Axes>)
#  [7e6ae17a] BioSequences v2.0.5
#   [336ed68f] CSV v0.9.11
#   [8f4d0f93] Conda v1.5.2
#   [a93c6f00] DataFrames v1.2.2
#   [31c24e10] Distributions v0.25.28
#   [c2308a5c] FASTX v1.2.0
#   [09f84164] HypothesisTests v0.10.6
#   [7073ff75] IJulia v1.23.2
#   [916415d5] Images v0.24.1
#   [96684042] InformationMeasures v0.3.1
#   [10e44e05] MATLAB v0.8.2
#   [f8716d33] MultipleTesting v0.5.0
#   [92933f4c] ProgressMeter v1.7.1
#   [438e738f] PyCall v1.92.5
#   [d330b81b] PyPlot v2.10.0
#   [6f49c342] RCall v0.13.12
#   [d2ef9438] Seaborn v1.0.0
# ...
